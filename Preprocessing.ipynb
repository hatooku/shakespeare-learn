# %%
import numpy as np
import pickle
import time

SONNET_LINES = 14
NUM_QUATRAINS = 3
QUATRAIN_LINES = 4
COUPLET_LINES = 2
NUM_SHKSP_SONNETS = 151

PUNCTUATION = [',', ':', '.', ';', '?', '!', '(', ')', '"', "'"]

SYLL_DICT = 'syll_dict.p'
STRESS_DICT = 'stress_dict.p'

############################################################
# Read in raw sonnets.
############################################################

def shksp_raw(filename='shakespeare.txt'):
    seqs = np.loadtxt(filename, delimiter='\n', dtype='str')
    return seqs

############################################################
# Different tokenizers per line.
############################################################

# simple_token1:
#   Checks back of each line for punctuation and if found, 
#   replaces with a single token of the punctuation and a 
#   newline character. Punctuation within line is attatched
#   to word on left.
def simple_token1(line):
    line = line.lower().lstrip().rstrip()
    line = line.split(' ')
    # Handle punctuation at end of line.
    last_word = list(line[-1])
    del line[-1]
    if last_word[-1] in PUNCTUATION:
        tmp = last_word[-1]
        del last_word[-1]
        line.append(''.join(last_word))
        line.append(tmp + '\n')
    else:
        line.append(''.join(last_word))
    return line

# simple_token2:
#   All punctuation are attached to word on left, no 
#   newline characters.
def simple_token2(line):
    line = line.lower().lstrip().rstrip()
    line = line.split(' ')
    return line

# simple_token3:
#   All punctuation attached to word on left. Newline
#   characters for each line.
def simple_token3(line):
    line = line.lower().lstrip().rstrip()
    line = line.split(' ')
    return line + ['\n']

# simple_token4:
#   Remove all punctuation, no newline character.
def simple_token4(line):
    line = line.lower().lstrip().rstrip()
    for punc in PUNCTUATION:
        line = line.replace(punc, '')
    line = line.split(' ')
    return line

############################################################
# Preprocess Shakespeare sonnets.
############################################################

def shksp_per_sonnet(tokenizer, filename='shakespeare.txt'):
    raw = shksp_raw(filename)
    sequences = []
    cursor = 0
    for sonnet in range(NUM_SHKSP_SONNETS):
        # Skip first line which is a number.
        cursor += 1
        # Setup sequence.
        seq = []
        for i in range(SONNET_LINES):
            seq += tokenizer(raw[cursor])
            cursor += 1
        sequences.append(seq)
    return sequences

def shksp_per_line(tokenizer, filename='shakespeare.txt'):
    raw = shksp_raw(filename)
    sequences = []
    cursor = 0
    for sonnet in range(NUM_SHKSP_SONNETS):
        # Skip first line which is a number.
        cursor += 1
        for i in range(SONNET_LINES):
            sequences.append(tokenizer(raw[cursor]))
            cursor += 1
    return sequences

def shksp_quatrains_and_couplets(tokenizer, filename='shakespeare.txt'):
    raw = shksp_raw(filename)
    quatrains = []
    couplets = []
    cursor = 0
    for sonnet in range(NUM_SHKSP_SONNETS):
        cursor += 1
        couplet = []
        for quatrain in range(NUM_QUATRAINS):
            quatrain = []
            for line in range(QUATRAIN_LINES):
                quatrain += tokenizer(raw[cursor])
                cursor += 1
            quatrains.append(quatrain)
        for line in range(COUPLET_LINES):
            couplet += tokenizer(raw[cursor])
            cursor += 1
        couplets.append(couplet)
    return quatrains, couplets

def shksp_quatrain_couplets_line(tokenizer, filename='shakespeare.txt'):
    raw = shksp_raw(filename)
    quatrains = []
    couplets = []
    cursor = 0
    for sonnet in range(NUM_SHKSP_SONNETS):
        cursor += 1
        couplet = []
        for quatrain in range(NUM_QUATRAINS):
            for line in range(QUATRAIN_LINES):
                quatrains.append(tokenizer(raw[cursor]))
                cursor += 1
        for line in range(COUPLET_LINES):
            couplets.append(tokenizer(raw[cursor]))
            cursor += 1
    return quatrains, couplets

# %%
############################################################
# Class to train HMM models.
############################################################
class HMM:

    def __init__(self, num_states):

        self.D = 0 # num of unique observations
        self.L = num_states # num of hidden states

        self.token_dict = {} # map of integers to tokens

        self.A = None # transition (row: from; col: to), 0-indexed
        self.PI = None # initial state distribution, 0-indexed
        self.O = None # observation (row: state; col: observation), 0-indexed

    def train(self, data, epsilon=0.001, scaling=True):
        X = self.registerObs(data)

        L = self.L
        D = self.D

        # Initialize Matrices
        self.A = self.normalize(np.random.rand(L, L))
        self.PI = self.normalize(np.random.rand(L))
        self.O = self.normalize(np.random.rand(L, D))

        norm_arr = []
        iterations = 0

        while (True):
            iterations += 1
            # E Step
            gamma_arr, xi_arr = self.computeMarginals(X, scaling)

            # M step (Computes marginals + Updates)
            change_norm = self.update(X, gamma_arr, xi_arr)
            print change_norm
            norm_arr.append(change_norm)

            # Stopping Condition
            if len(norm_arr) > 1 and norm_arr[-1] / norm_arr[0] < epsilon:
                print "iterations:", iterations
                break

        # print self.PI
        # print self.A
        # print self.O

        return (self.token_dict, self.PI, self.A, self.O)

    """ Registers observations as integers and returns data transformed into
    integers. """
    def registerObs(self, data):
        # Reset Variables
        self.D = 0
        self.token_dict = {}

        X = [] # data transformed into integers corresponding to tokens
        for seq in data:
            X_i = [] # this sequence transformed into integers
            for token in seq:
                if token not in self.token_dict:
                    self.token_dict[token] = self.D
                    self.D += 1
                X_i.append(self.token_dict[token])
            X.append(X_i)
        return X

    """ Makes all rows add up to 1 """
    @staticmethod
    def normalize(matrix):
        if len(matrix.shape) == 1:
            return matrix / matrix.sum()
        sums = matrix.sum(axis=1)
        return matrix / sums.reshape(sums.shape[0], 1)

    def forwardBackward(self, seq, scaling=True):
        """ This function computes alpha and beta values for a sequence
            using the Forward-Backward algorithm.
        """
        M = len(seq) # length of given sequence
        L = self.L # num of states

        alphas = np.zeros((M, L)) # row: position; col: state
        betas = np.zeros((M, L)) # row: position; col: state

        # FORWARD ALGORITHM
        for i in range(M): # For each observation
            for s in range(L): # For each state
                # Base case
                if i == 0:
                    alphas[i, s] = self.O[s, seq[0]] * self.PI[s]
                else:
                    sum = 0
                    # For each previous state
                    for prev in range(L):
                        sum += alphas[i-1, prev] * self.A[prev, s]
                    alphas[i, s] = sum * self.O[s, seq[i]]
            # Scaling
            if scaling:
                scale = np.sum(alphas[i])
                alphas[i] = alphas[i] / scale

        # BACKWARD ALGORITHM
        for i in reversed(range(M)): # For each observation
            for s in range(L): # For each state
                # Base case
                if i == M-1:
                    betas[i, s] = 1
                else:
                    # For each next state
                    for next in range(L):
                        betas[i, s] += betas[i+1, next] * \
                                       self.A[s, next] * self.O[next, seq[i+1]]
            # Scaling
            if scaling:
                scale = np.sum(betas[i])
                betas[i] = betas[i] / scale

        return (alphas, betas)

    def computeMarginals(self, X, scaling=True):
        # Calculate alphas and betas for all sequences
        L = self.L
        alphas_arr = []
        betas_arr = []
        for seq in X:
            alphas, betas = self.forwardBackward(seq, scaling)
            alphas_arr.append(alphas)
            betas_arr.append(betas)
        # P(y_i = z)
        gamma_arr = [] # Indexed by: # Sequence, Position, State

        # P(y_i = prev, y_i+1 = next)
        xi_arr = [] # Indexed by: # Sequence, Position of Prev, Prev, Next

        # Compute Gammas
        for j in range(len(X)): # iterate over all sequences
            seq_len = len(X[j])
            alphas = alphas_arr[j]
            betas = betas_arr[j]

            # gammas for this sequence
            gamma = np.zeros((seq_len, L))

            for i in range(seq_len):
                for state in range(L):
                    # just numerator
                    gamma[i, state] = alphas[i, state] * betas[i, state]
                # divide by denominator
                gamma[i] = gamma[i] / gamma[i].sum()

            gamma_arr.append(gamma)

        # Compute Xi's
        for j in range(len(X)): # iterate over all sequences
            seq = X[j]
            seq_len = len(seq)
            alphas = alphas_arr[j]
            betas = betas_arr[j]

            # xi's for this sequence
            xi = np.zeros((seq_len-1, L, L))

            for i in range(seq_len-1):
                for prev in range(L):
                    for next in range(L):
                        # just numerator
                        xi[i, prev, next] = alphas[i, prev] * \
                                            self.O[next, seq[i+1]] * \
                                            self.A[prev, next] * \
                                            betas[i+1, next]
                # divide by denominator
                xi[i] = xi[i] / xi[i].sum()

            xi_arr.append(xi)

        return (gamma_arr, xi_arr)

    def update(self, X, gamma_arr, xi_arr):
        L = self.L # num states
        D = self.D # num unique tokens

        # new matrices
        PI = np.zeros(self.PI.shape)
        A = np.zeros(self.A.shape)
        O = np.zeros(self.O.shape)

        # update PI (initial distribution matrix)
        for state in range(L):
            prob_sum = 0
            for j in range(len(X)): # iterate over all sequences
                prob_sum += gamma_arr[j][0, state]

            PI[state] = prob_sum / len(X) # average across sequences

        # Make sure numbers add up to 1
        np.testing.assert_almost_equal(PI.sum(), 1)

        # Update A (transition matrix)
        for prev in range(L):
            for next in range(L):
                numerator = 0
                denominator = 0

                for j in range(len(X)): # iterate over all sequences
                    # for each index in seq excluding last index
                    for i in range(len(X[j])-1):

                        numerator += xi_arr[j][i, prev, next]
                        denominator += gamma_arr[j][i, prev]

                # UPDATE A_{prev, next}
                A[prev, next] = numerator / denominator

            # Make sure rows add up to 1
            np.testing.assert_almost_equal(A[prev].sum(), 1)

        # update O (emission matrix)
        for state in range(L):
            for token in range(D):
                numerator = 0
                denominator = 0

                for j in range(len(X)): # iterate over all sequences
                    for i in range(len(X[j])): # for each index in seq
                        prob = gamma_arr[j][i, state]

                        if X[j][i] == token: # indicator function
                            numerator += prob
                        denominator += prob

                O[state, token] = numerator / denominator

            # Make sure rows add up to 1
            np.testing.assert_almost_equal(O[state].sum(), 1)

        # frobenius norm of the differences between update and previous matrices
        change_norm = np.linalg.norm(self.A - A) + np.linalg.norm(self.O - O) \
                      + np.linalg.norm(self.PI - PI)

        # update matrices
        self.O = O
        self.PI = PI
        self.A = A

        return change_norm

# %%
############################################################
# Generate from trained models.
############################################################
# Length is number of syllables to generate. (Generally 10)
def gen_txt(trans, emiss, init, word_map, 
            syll_dict, stress_dict, length=10, 
            space_symb=' '):
    # Verify that the model is functional and setup.
    num_states = len(trans)
    num_words = len(emiss[0])
    assert (num_states == len(trans[0])), 'Transition matrix is not square.'
    assert (num_states == len(emiss)), 'Emission matrix not correct dimensions.'
    
    # Prepare to iterate for words.
    build = ''
    curr_state = np.random.choice(num_states, p=init)
    curr_length = 0
    curr_stress = 0
    
    # Build the sequence.
    while curr_length < length:
        # Select random word based on emission matrix.
        nxt_token = int(np.random.choice(num_words, p=emiss[int(curr_state)]))
        word = word_map[nxt_token].rstrip('.,?!;:()')
        print word
        
        # Check that word isn't too long and is stressed correctly.
        while (syll_dict[word] + curr_stress > length) or (stress_dict[word] != curr_stress):
                nxt_token = int(np.random.choice(num_words, p=emiss[int(curr_state)]))
                word = word_map[nxt_token].rstrip('.,?!;:()').lstrip('(')
                print word
        
        build += word_map[nxt_token] + space_symb
        curr_length += syll_dict[word]
        curr_stress = (curr_stress + syll_dict[word]) % 2
        
        # Go to next state.
        curr_state = np.random.choice(num_states, p=trans[int(curr_state)])
    return build

# %%
# Test training.
start_time = time.time()

q, c = shksp_quatrain_couplets_line(simple_token2)
q_hmm = HMM(10)
token_dict, PI, A, O = q_hmm.train(q)

print("--- %s seconds ---" % (time.time() - start_time))
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-79-ac64a205f070> in <module>()
#       4 q, c = shksp_quatrain_couplets_line(simple_token2)
#       5 q_hmm = HMM(10)
# ----> 6 token_dict, PI, A, O = q_hmm.train(q)
#       7
#       8 print("--- %s seconds ---" % (time.time() - start_time))
#
# <ipython-input-71-958b6968f403> in train(self, data, epsilon, scaling)
#      35
#      36             # M step (Computes marginals + Updates)
# ---> 37             change_norm = self.update(X, gamma_arr, xi_arr)
#      38             print change_norm
#      39             norm_arr.append(change_norm)
#
# <ipython-input-71-958b6968f403> in update(self, X, gamma_arr, xi_arr)
#     224                         prob = gamma_arr[j][i, state]
#     225
# --> 226                         if X[j][i] == token: # indicator function
#     227                             numerator += prob
#     228                         denominator += prob
#
# KeyboardInterrupt:

# %%
trans = q_hmm.A
emiss = q_hmm.O
init = q_hmm.PI
word_map = q_hmm.token_dict
word_map = dict((v,k) for k,v in word_map.iteritems())
syll_dict, stress_dic = load_syll_stress_dicts()
gen_txt(trans, emiss, init, word_map, 
        syll_dict, stress_dic)
# Out:
# is
# indeed
# poet's
# sullied
# starved
# frame
# trespass
# much
# ah
# unseeing
# hymns
# "is, poet's sullied starved unseeing hymns "

# %%
save_file = open('matrices/10-state-quatrains-transition.p', 'wb')
pickle.dump(trans, save_file)
save_file.close()

save_file = open('matrices/10-state-quatrains-emission.p', 'wb')
pickle.dump(emiss, save_file)
save_file.close()

save_file = open('matrices/10-state-quatrains-wordmap.p', 'wb')
pickle.dump(word_map, save_file)
save_file.close()

save_file = open('matrices/10-state-quatrains-init.p', 'wb')
pickle.dump(init, save_file)
save_file.close()

# %%
# Set up pickle dictionary for syllable processing. 
# DO NOT RUN AFTER COMPLETING DICTIONARY!
import pickle
syll_dict = {'from' : 1}
save_file = open(SYLL_DICT, 'wb')
pickle.dump(syll_dict, save_file)
save_file.close()

# %%
from wordnik import *

# Method for assisting in creating syllables dict.
def make_syll_dict(lines):
    # Setup API connections.
    apiUrl = 'http://api.wordnik.com/v4'
    apiKey = '552b2562693245ea105020d08c904c58324d0d2b793995895'
    client = swagger.ApiClient(apiKey, apiUrl)
    wordApi = WordApi.WordApi(client)
    
    # Read in old dictionary.
    save_file = open(SYLL_DICT, 'rb')
    syll_dict = pickle.load(save_file)
    save_file.close()
    
    for line in lines:
        for word in line:
            if syll_dict.get(word) == None:
                try_api = wordApi.getHyphenation(word)
                if try_api != None:
                    syll_dict[word] = len(try_api)
                else:
                    print word, ':', line
                    count = input()
                    syll_dict[word] = count
        save_file = open(SYLL_DICT, 'wb')
        pickle.dump(syll_dict, save_file)
        save_file.close()
        
    return syll_dict

# Method for assisting in creating stress dict.
# Note that 0 = unstressed
#           1 = stressed
def make_stress_dict(lines, syll_dict):
    stress_dict = {}
    for line in lines:
        curr_state = 0
        for word in line:
            stress_dict[word] = curr_state
            curr_state = (curr_state + syll_dict[word]) % 2
    return stress_dict
            
# Load syllable and stress dictionaries.
def load_syll_stress_dicts():
    syll_file = open(SYLL_DICT, 'rb')
    syll_dict = pickle.load(syll_file)
    syll_file.close()
    
    stress_file = open(STRESS_DICT, 'rb')
    stress_dict = pickle.load(stress_file)
    stress_file.close()
    
    return syll_dict, stress_dict

# %%
all_lines = shksp_per_line(simple_token4)
print len(all_lines)
# Out:
# 2114

# %%
make_syll_dict(all_lines)
# Out:
# beautys : ['that', 'thereby', 'beautys', 'rose', 'might', 'never', 'die']
# 2
# feedst : ['feedst', 'thy', 'lights', 'flame', 'with', 'self-substantial', 'fuel']
# 1
# worlds : ['thou', 'that', 'art', 'now', 'the', 'worlds', 'fresh', 'ornament']
# 1
# makst : ['and', 'tender', 'churl', 'makst', 'waste', 'in', 'niggarding']
# 1
# youths : ['thy', 'youths', 'proud', 'livery', 'so', 'gazed', 'on', 'now']
# 1
# feelst : ['and', 'see', 'thy', 'blood', 'warm', 'when', 'thou', 'feelst', 'it', 'cold']
# 1
# mothers : ['thou', 'art', 'thy', 'mothers', 'glass', 'and', 'she', 'in', 'thee']
# 2
# natures : ['natures', 'bequest', 'gives', 'nothing', 'but', 'doth', 'lend']
# 2
# th : ['which', 'used', 'lives', 'th', 'executor', 'to', 'be']
# 1
# oer-snowed : ['beauty', 'oer-snowed', 'and', 'bareness', 'every', 'where']
# 2
# summers : ['then', 'were', 'not', 'summers', 'distillation', 'left']
# 2
# thats : ['thats', 'for', 'thy', 'self', 'to', 'breed', 'another', 'thee']
# 1
# hearst : ['music', 'to', 'hear', 'why', 'hearst', 'thou', 'music', 'sadly']
# 1
# lovst : ['why', 'lovst', 'thou', 'that', 'which', 'thou', 'receivst', 'not', 'gladly']
# 1
# receivst : ['why', 'lovst', 'thou', 'that', 'which', 'thou', 'receivst', 'not', 'gladly']
# 2
# widows : ['is', 'it', 'for', 'fear', 'to', 'wet', 'a', 'widows', 'eye']
# 2
# consumst : ['that', 'thou', 'consumst', 'thy', 'self', 'in', 'single', 'life']
# 2
# childrens : ['by', 'childrens', 'eyes', 'her', 'husbands', 'shape', 'in', 'mind']
# 22
# husbands : ['by', 'childrens', 'eyes', 'her', 'husbands', 'shape', 'in', 'mind']
# 2
# murdrous : ['that', 'on', 'himself', 'such', 'murdrous', 'shame', 'commits']
# 2
# bearst : ['for', 'shame', 'deny', 'that', 'thou', 'bearst', 'love', 'to', 'any']
# 1
# gainst : ['that', 'gainst', 'thy', 'self', 'thou', 'stickst', 'not', 'to', 'conspire']
# 1
# stickst : ['that', 'gainst', 'thy', 'self', 'thou', 'stickst', 'not', 'to', 'conspire']
# 1
# growst : ['as', 'fast', 'as', 'thou', 'shalt', 'wane', 'so', 'fast', 'thou', 'growst']
# 1
# bestowst : ['and', 'that', 'fresh', 'blood', 'which', 'youngly', 'thou', 'bestowst']
# 2
# oer : ['and', 'sable', 'curls', 'all', 'silvered', 'oer', 'with', 'white']
# 1
# selfs : ['your', 'self', 'again', 'after', 'your', 'selfs', 'decease']
# 1
# owst : ['nor', 'lose', 'possession', 'of', 'that', 'fair', 'thou', 'owst']
# 1
# wandrest : ['nor', 'shall', 'death', 'brag', 'thou', 'wandrest', 'in', 'his', 'shade']
# 2
# lions : ['devouring', 'time', 'blunt', 'thou', 'the', 'lions', 'paws']
# 1
# tigers : ['pluck', 'the', 'keen', 'teeth', 'from', 'the', 'fierce', 'tigers', 'jaws']
# 2
# fleetst : ['make', 'glad', 'and', 'sorry', 'seasons', 'as', 'thou', 'fleetst']
# 1
# whateer : ['and', 'do', 'whateer', 'thou', 'wilt', 'swift-footed', 'time']
# 2
# womans : ['a', 'womans', 'face', 'with', 'natures', 'own', 'hand', 'painted']
# 2
# womens : ['with', 'shifting', 'change', 'as', 'is', 'false', 'womens', 'fashion']
# 2
# mens : ['which', 'steals', 'mens', 'eyes', 'and', 'womens', 'souls', 'amazeth']
# 1
# seas : ['with', 'sun', 'and', 'moon', 'with', 'earth', 'and', 'seas', 'rich', 'gems']
# 1
# aprils : ['with', 'aprils', 'first-born', 'flowers', 'and', 'all', 'things', 'rare']
# 2
# heavens : ['that', 'heavens', 'air', 'in', 'this', 'huge', 'rondure', 'hems']
# 2
# gavst : ['thou', 'gavst', 'me', 'thine', 'not', 'to', 'give', 'back', 'again']
# 1
# strengths : ['whose', 'strengths', 'abundance', 'weakens', 'his', 'own', 'heart']
# 1
# oercharged : ['oercharged', 'with', 'burthen', 'of', 'mine', 'own', 'loves', 'might']
# 2
# tis : ['my', 'body', 'is', 'the', 'frame', 'wherein', 'tis', 'held']
# 1
# painters : ['and', 'perspective', 'it', 'is', 'best', 'painters', 'art']
# 2
# bodys : ['to', 'work', 'my', 'mind', 'when', 'bodys', 'works', 'expired']
# 2
# eithers : ['and', 'each', 'though', 'enemies', 'to', 'eithers', 'reign']
# 2
# gildst : ['when', 'sparkling', 'stars', 'twire', 'not', 'thou', 'gildst', 'the', 'even']
# 1
# mans : ['desiring', 'this', 'mans', 'art', 'and', 'that', 'mans', 'scope']
# 1
# stoln : ['hath', 'dear', 'religious', 'love', 'stoln', 'from', 'mine', 'eye']
# 1
# bettring : ['compare', 'them', 'with', 'the', 'bettring', 'of', 'the', 'time']
# 2
# oertake : ['to', 'let', 'base', 'clouds', 'oertake', 'me', 'in', 'my', 'way']
# 2
# bravry : ['hiding', 'thy', 'bravry', 'in', 'their', 'rotten', 'smoke']
# 2
# fortunes : ['so', 'i', 'made', 'lame', 'by', 'fortunes', 'dearest', 'spite']
# 2
# pourst : ['while', 'thou', 'dost', 'breathe', 'that', 'pourst', 'into', 'my', 'verse']
# 1
# whos : ['for', 'whos', 'so', 'dumb', 'that', 'cannot', 'write', 'to', 'thee']
# 1
# ist : ['and', 'what', 'ist', 'but', 'mine', 'own', 'when', 'i', 'praise', 'thee']
# 1
# deservst : ['that', 'due', 'to', 'thee', 'which', 'thou', 'deservst', 'alone']
# 2
# hates : ['to', 'bear', 'greater', 'wrong', 'than', 'hates', 'known', 'injury']
# 1
# knowst : ['thou', 'dost', 'love', 'her', 'because', 'thou', 'knowst', 'i', 'love', 'her']
# 1
# suffring : ['suffring', 'my', 'friend', 'for', 'my', 'sake', 'to', 'approve', 'her']
# 2
# heres : ['but', 'heres', 'the', 'joy', 'my', 'friend', 'and', 'i', 'are', 'one']
# 1
# lifes : ['until', 'lifes', 'composition', 'be', 'recured']
# 1
# pictures : ['mine', 'eye', 'my', 'heart', 'thy', 'pictures', 'sight', 'would', 'bar']
# 2
# perfectst : ['therefore', 'desire', 'of', 'perfectst', 'love', 'being', 'made']
# 2
# helens : ['on', 'helens', 'cheek', 'all', 'art', 'of', 'beauty', 'set']
# 2
# wars : ['nor', 'mars', 'his', 'sword', 'nor', 'wars', 'quick', 'fire', 'shall', 'burn']
# 1
# sendst : ['is', 'it', 'thy', 'spirit', 'that', 'thou', 'sendst', 'from', 'thee']
# 1
# oerworn : ['with', 'times', 'injurious', 'hand', 'crushed', 'and', 'oerworn']
# 2
# hes : ['and', 'all', 'those', 'beauties', 'whereof', 'now', 'hes', 'king']
# 1
# oersways : ['but', 'sad', 'mortality', 'oersways', 'their', 'power']
# 2
# battring : ['against', 'the', 'wrackful', 'siege', 'of', 'battring', 'days']
# 2
# anothers : ['making', 'no', 'summer', 'of', 'anothers', 'green']
# 3
# slanders : ['for', 'slanders', 'mark', 'was', 'ever', 'yet', 'the', 'fair']
# 2
# presentst : ['and', 'thou', 'presentst', 'a', 'pure', 'unstained', 'prime']
# 2
# perceivst : ['this', 'thou', 'perceivst', 'which', 'makes', 'thy', 'love', 'more', 'strong']
# 2
# wretchs : ['the', 'coward', 'conquest', 'of', 'a', 'wretchs', 'knife']
# 1
# twixt : ['as', 'twixt', 'a', 'miser', 'and', 'his', 'wealth', 'is', 'found']
# 1
# dials : ['thou', 'by', 'thy', 'dials', 'shady', 'stealth', 'mayst', 'know']
# 1
# learneds : ['have', 'added', 'feathers', 'to', 'the', 'learneds', 'wing']
# 1
# oer-read : ['which', 'eyes', 'not', 'yet', 'created', 'shall', 'oer-read']
# 2
# oerlook : ['and', 'therefore', 'mayst', 'without', 'attaint', 'oerlook']
# 2
# scaped : ['ah', 'do', 'not', 'when', 'my', 'heart', 'hath', 'scaped', 'this', 'sorrow']
# 1
# manys : ['in', 'manys', 'looks', 'the', 'false', 'hearts', 'history']
# 2
# eves : ['how', 'like', 'eves', 'apple', 'doth', 'thy', 'beauty', 'grow']
# 1
# decembers : ['what', 'old', 'decembers', 'bareness', 'everywhere']
# 3
# lilys : ['nor', 'did', 'i', 'wonder', 'at', 'the', 'lilys', 'white']
# 2
# forgetst : ['where', 'art', 'thou', 'muse', 'that', 'thou', 'forgetst', 'so', 'long']
# 2
# spendst : ['spendst', 'thou', 'thy', 'fury', 'on', 'some', 'worthless', 'song']
# 1
# preventst : ['so', 'thou', 'preventst', 'his', 'scythe', 'and', 'crooked', 'knife']
# 2
# intermixed : ['but', 'best', 'is', 'best', 'if', 'never', 'intermixed']
# 3
# dyers : ['to', 'what', 'it', 'works', 'in', 'like', 'the', 'dyers', 'hand']
# 2
# oer-green : ['so', 'you', 'oer-green', 'my', 'bad', 'my', 'good', 'allow']
# 2
# adders : ['of', 'others', 'voices', 'that', 'my', 'adders', 'sense']
# 2
# rudst : ['for', 'if', 'it', 'see', 'the', 'rudst', 'or', 'gentlest', 'sight']
# 1
# deformedst : ['the', 'most', 'sweet', 'favour', 'or', 'deformedst', 'creature']
# 2
# monarchs : ['drink', 'up', 'the', 'monarchs', 'plague', 'this', 'flattery']
# 2
# greeing : ['mine', 'eye', 'well', 'knows', 'what', 'with', 'his', 'gust', 'is', 'greeing']
# 2
# sharpst : ['tan', 'sacred', 'beauty', 'blunt', 'the', 'sharpst', 'intents']
# 1
# altring : ['divert', 'strong', 'minds', 'to', 'the', 'course', 'of', 'altring', 'things']
# 2
# wandring : ['it', 'is', 'the', 'star', 'to', 'every', 'wandring', 'bark']
# 2
# sickles : ['within', 'his', 'bending', 'sickles', 'compass', 'come']
# 2
# neer-cloying : ['even', 'so', 'being', 'full', 'of', 'your', 'neer-cloying', 'sweetness']
# 3
# yhave : ['as', 'i', 'by', 'yours', 'yhave', 'passed', 'a', 'hell', 'of', 'time']
# 1
# wondring : ['not', 'wondring', 'at', 'the', 'present', 'nor', 'the', 'past']
# 2
# weret : ['weret', 'aught', 'to', 'me', 'i', 'bore', 'the', 'canopy']
# 2
# playst : ['how', 'oft', 'when', 'thou', 'my', 'music', 'music', 'playst']
# 1
# swayst : ['with', 'thy', 'sweet', 'fingers', 'when', 'thou', 'gently', 'swayst']
# 1
# woods : ['at', 'the', 'woods', 'boldness', 'by', 'thee', 'blushing', 'stand']
# 1
# judgments : ['thy', 'black', 'is', 'fairest', 'in', 'my', 'judgments', 'place']
# 2
# sweetst : ['but', 'slave', 'to', 'slavery', 'my', 'sweetst', 'friend', 'must', 'be']
# 1
# whoeer : ['whoeer', 'keeps', 'me', 'let', 'my', 'heart', 'be', 'his', 'guard']
# 2
# putst : ['thou', 'usurer', 'that', 'putst', 'forth', 'all', 'to', 'use']
# 1
# needst : ['what', 'needst', 'thou', 'wound', 'with', 'cunning', 'when', 'thy', 'might']
# 1
# oerpressed : ['is', 'more', 'than', 'my', 'oerpressed', 'defence', 'can', 'bide']
# 2
# beds : ['robbed', 'others', 'beds', 'revenues', 'of', 'their', 'rents']
# 1
# infants : ['not', 'prizing', 'her', 'poor', 'infants', 'discontent']
# 2
# runst : ['so', 'runst', 'thou', 'after', 'that', 'which', 'flies', 'from', 'thee']
# 1
# servants : ['then', 'soul', 'live', 'thou', 'upon', 'thy', 'servants', 'loss']
# 2
# theres : ['and', 'death', 'once', 'dead', 'theres', 'no', 'more', 'dying', 'then']
# 1
# keepst : ['o', 'cunning', 'love', 'with', 'tears', 'thou', 'keepst', 'me', 'blind']
# 1
# frownst : ['on', 'whom', 'frownst', 'thou', 'that', 'i', 'do', 'fawn', 'upon']
# 1
# lourst : ['nay', 'if', 'thou', 'lourst', 'on', 'me', 'do', 'i', 'not', 'spend']
# 1
# dians : ['a', 'maid', 'of', 'dians', 'this', 'advantage', 'found']
# 2
# {'fawn': 1,
#  'pardon': 2,
#  'both': 1,
#  'yellow': 2,
#  'four': 1,
#  'hath': 1,
#  'woods': 1,
#  'sleep': 1,
#  "friend's": 1,
#  'hanging': 2,
#  'mansion': 2,
#  'appetite': 3,
#  'captain': 2,
#  'hate': 1,
#  'poorly': 2,
#  'whose': 1,
#  'feeding': 2,
#  'effectually': 4,
#  'granting': 2,
#  'sweetest': 2,
#  'presents': 2,
#  "there's": 1,
#  'whatsoever': 4,
#  'under': 2,
#  'lord': 1,
#  'sorry': 2,
#  'pride': 1,
#  'sway': 1,
#  'worth': 1,
#  'wondrous': 2,
#  'discased': 2,
#  'dispense': 2,
#  'hadst': 1,
#  'inhearse': 2,
#  "women's": 2,
#  'every': 3,
#  'foul': 1,
#  'nourished': 2,
#  "o'er-read": 2,
#  'prizing': 2,
#  'uttering': 3,
#  'prize': 1,
#  'unrest': 2,
#  'graced': 1,
#  'succession': 3,
#  'graces': 1,
#  'triumph': 2,
#  'enjoy': 2,
#  'charter': 2,
#  'force': 1,
#  'suffring': 2,
#  'tired': 1,
#  'awake': 2,
#  'razed': 1,
#  'out-going': 3,
#  'tires': 1,
#  'crave': 1,
#  'persuade': 2,
#  'lourst': 1,
#  'happies': 2,
#  'quill': 1,
#  'even': 2,
#  'beated': 2,
#  'evermore': 3,
#  'hide': 1,
#  "ne'er": 1,
#  'solemn': 2,
#  'thunder': 2,
#  'fingers': 2,
#  'liberty': 3,
#  'children': 2,
#  'lights': 1,
#  'worser': 2,
#  'oaths': 1,
#  'above': 2,
#  'feelst': 1,
#  'matcheth': 2,
#  'new': 1,
#  'increasing': 1,
#  'ever': 2,
#  'eves': 1,
#  'told': 1,
#  'deemed': 1,
#  'merchandized': 3,
#  'sinks': 1,
#  'never': 2,
#  'here': 1,
#  'herd': 1,
#  'beck': 1,
#  "sweet'st": 1,
#  'pursuit': 2,
#  'amazeth': 3,
#  'active': 2,
#  'spies': 1,
#  'a-doting': 3,
#  'dry': 1,
#  'resty': 2,
#  'substance': 2,
#  'gaol': 1,
#  'leaves': 1,
#  'climbed': 1,
#  'credit': 2,
#  'oer-green': 2,
#  'smoke': 1,
#  'permit': 2,
#  'bettered': 2,
#  'mistake': 2,
#  'settled': 2,
#  'politic': 3,
#  'golden': 2,
#  'swearing': 2,
#  'divide': 2,
#  'motley': 2,
#  'blessed-fair': 3,
#  'sorrows': 2,
#  'patience': 2,
#  'stern': 1,
#  'glance': 1,
#  'perfectst': 2,
#  "light's": 1,
#  'plot': 1,
#  'would': 1,
#  'crowning': 2,
#  "world's": 1,
#  'junes': 1,
#  'music': 2,
#  'therefore': 2,
#  'centre': 2,
#  'survive': 2,
#  'gilding': 2,
#  'tell': 1,
#  'breathe': 1,
#  'leese': 1,
#  'unbless': 2,
#  'holy': 2,
#  'wary': 2,
#  'brings': 1,
#  'wars': 1,
#  'muse': 1,
#  'hurt': 1,
#  'grief': 1,
#  'glass': 1,
#  'warm': 1,
#  'excellent': 3,
#  'continual': 3,
#  'ward': 1,
#  'hold': 1,
#  'striving': 2,
#  'must': 1,
#  'me': 1,
#  'join': 1,
#  'room': 1,
#  'err': 1,
#  'rights': 1,
#  'work': 1,
#  'eclipse': 2,
#  'roof': 1,
#  'meadows': 2,
#  'ere': 1,
#  'runst': 1,
#  'leaped': 1,
#  'revenues': 3,
#  'my': 1,
#  'example': 3,
#  'shook': 1,
#  'phrase': 1,
#  'fresher': 1,
#  'wane': 1,
#  'unjust': 2,
#  'honey': 2,
#  'kingdoms': 2,
#  'want': 1,
#  'keep': 1,
#  'worse': 1,
#  'ceremony': 4,
#  'sought': 1,
#  "consum'st": 2,
#  'gusts': 1,
#  'provide': 2,
#  'dignifies': 3,
#  'travel': 2,
#  'indirectly': 4,
#  'feature': 2,
#  'wights': 1,
#  'how': 1,
#  'hot': 1,
#  'writers': 2,
#  'answer': 2,
#  'gate': 1,
#  'dignified': 3,
#  "o'er-snowed": 2,
#  'blanks': 1,
#  'beauty': 2,
#  'less': 1,
#  'shorn': 1,
#  'after': 2,
#  'wrong': 1,
#  'lay': 1,
#  'lap': 1,
#  'wronk': 1,
#  'youths': 1,
#  "rud'st": 1,
#  'revolt': 2,
#  'greet': 1,
#  'purging': 2,
#  'wink': 1,
#  'maintain': 2,
#  'green': 1,
#  'keeps': 1,
#  'enjoyer': 3,
#  'alack': 2,
#  'mightier': 2,
#  'wouldst': 1,
#  'wind': 1,
#  'bed-vow': 2,
#  'determinate': 4,
#  'couplement': 3,
#  'helens': 2,
#  'after-loss': 3,
#  'office': 2,
#  'consent': 2,
#  'profaned': 2,
#  'sickly': 2,
#  'fortify': 3,
#  'ghastly': 2,
#  'budding': 2,
#  "bestow'st": 2,
#  'wrought': 1,
#  'before': 2,
#  'better': 2,
#  'fade': 1,
#  'carve': 1,
#  'hidden': 2,
#  'savour': 2,
#  'then': 1,
#  'them': 1,
#  'blots': 1,
#  'weakness': 2,
#  'thee': 1,
#  "truth's": 1,
#  'break': 1,
#  "winter's": 2,
#  'diseased': 2,
#  'they': 1,
#  'glazed': 1,
#  'one': 1,
#  'silver': 2,
#  'shadows': 2,
#  'rhetoric': 3,
#  'brightness': 2,
#  'slavery': 3,
#  'rocks': 1,
#  'herald': 2,
#  'victories': 3,
#  'needing': 2,
#  'each': 1,
#  'wantonly': 3,
#  'dulness': 2,
#  'went': 1,
#  'side': 1,
#  'luck': 1,
#  'true-telling': 3,
#  'woes': 1,
#  'concord': 2,
#  "'will'": 1,
#  'taught': 1,
#  'forgot': 2,
#  'misprision': 3,
#  'whit': 1,
#  'truant': 2,
#  'array': 2,
#  'borne': 1,
#  'contend': 2,
#  'large': 1,
#  'decree': 2,
#  'god': 1,
#  'frownst': 1,
#  'forty': 2,
#  "run'st": 1,
#  'content': 2,
#  'laid': 1,
#  'heart-inflaming': 4,
#  'heavenly': 3,
#  'got': 1,
#  'marigold': 3,
#  'forth': 1,
#  'assured': 2,
#  'written': 2,
#  'fadeth': 2,
#  'hang': 1,
#  'deceived': 2,
#  'eternal': 3,
#  'given': 2,
#  'free': 1,
#  'mourning': 2,
#  'mistaking': 3,
#  'bestow': 2,
#  'whereupon': 3,
#  'rain': 1,
#  'rearward': 2,
#  'crowned': 1,
#  'mistress': 2,
#  'knit': 1,
#  "receiv'st": 2,
#  'created': 2,
#  'days': 1,
#  'ist': 1,
#  'bears': 1,
#  'renew': 2,
#  'tempting': 2,
#  'murdrous': 2,
#  'tied': 1,
#  'potions': 2,
#  'loud': 1,
#  'ruinate': 3,
#  'penury': 3,
#  'separable': 4,
#  'untutored': 3,
#  'already': 3,
#  'hearsay': 2,
#  "'greeing": 2,
#  'rank': 1,
#  'hearing': 2,
#  'workings': 2,
#  'featured': 2,
#  'another': 3,
#  'sober': 3,
#  'filching': 2,
#  'exchequer': 3,
#  'usurer': 3,
#  'top': 1,
#  'hawks': 1,
#  'millioned': 2,
#  'master': 2,
#  'too': 1,
#  'dwell': 1,
#  'bodys': 2,
#  'hearst': 1,
#  'bitter': 2,
#  'monuments': 3,
#  'saith': 1,
#  'lodged': 1,
#  'broils': 1,
#  'feathers': 2,
#  'griefs': 1,
#  'took': 1,
#  'wisdom': 2,
#  'wardrobe': 2,
#  "youth's": 1,
#  'travelled': 2,
#  'character': 3,
#  'begins': 2,
#  'distance': 2,
#  'bestowst': 2,
#  'coward': 2,
#  "mother's": 2,
#  'bitterness': 3,
#  'idly': 2,
#  'matter': 2,
#  'idle': 2,
#  'inheritors': 4,
#  'flame': 1,
#  'friend': 1,
#  'deserving': 3,
#  'knights': 1,
#  'feeling': 2,
#  'powers': 2,
#  'swift-footed': 3,
#  'sendst': 1,
#  'fashion': 2,
#  'sees': 1,
#  'gaudy': 2,
#  "mind's": 1,
#  'modern': 2,
#  'mind': 1,
#  'mine': 1,
#  'spent': 1,
#  'manner': 2,
#  'amiss': 2,
#  'bewailed': 2,
#  "deserv'st": 2,
#  'churl': 1,
#  'seem': 1,
#  'seek': 1,
#  'tells': 1,
#  'contents': 2,
#  'praising': 2,
#  'forgive': 2,
#  'strength': 1,
#  'snow': 1,
#  'chest': 1,
#  'subjects': 2,
#  'scaped': 1,
#  'laughed': 1,
#  'pilgrimage': 3,
#  'rider': 2,
#  'maiden': 2,
#  'though': 1,
#  'object': 2,
#  'dial': 2,
#  'clears': 1,
#  'errors': 2,
#  'disarmed': 2,
#  'grave': 1,
#  'shalt': 1,
#  'constancy': 3,
#  'foist': 1,
#  'flow': 1,
#  'breathes': 1,
#  'steeled': 1,
#  'points': 1,
#  'wrecked': 1,
#  'fitted': 2,
#  'reserve': 2,
#  'discontent': 3,
#  'bait': 1,
#  'queen': 1,
#  'ending': 2,
#  'poison': 2,
#  'earth': 1,
#  'bail': 1,
#  'enjoyed': 2,
#  'touches': 2,
#  'busy': 2,
#  'proposed': 2,
#  'spite': 1,
#  'herself': 2,
#  'cupid': 2,
#  'mens': 1,
#  'bliss': 1,
#  'touched': 1,
#  'rich': 1,
#  'pursuing': 3,
#  'mend': 1,
#  'wandrest': 2,
#  "'thou": 1,
#  'borrowed': 2,
#  'do': 2,
#  'blenches': 2,
#  'forsworn': 2,
#  'gainst': 1,
#  'stop': 1,
#  'perceive': 2,
#  'leisure': 2,
#  'raiment': 2,
#  'gored': 1,
#  'bootless': 2,
#  'despite': 2,
#  'report': 2,
#  'aught': 1,
#  'saturn': 2,
#  'seemly': 2,
#  'runs': 1,
#  'bar': 1,
#  'exchanged': 2,
#  'beseem': 2,
#  'thrusts': 1,
#  'doting': 2,
#  'twice': 1,
#  'eyelids': 2,
#  'esteeming': 3,
#  'hasten': 2,
#  'steal': 1,
#  'thanks': 1,
#  'unprovident': 4,
#  'penance': 2,
#  "wond'ring": 2,
#  'unrespected': 3,
#  'fair': 1,
#  'habit': 2,
#  'imitate': 3,
#  'tillage': 2,
#  'light': 1,
#  'proclaims': 2,
#  'depends': 2,
#  'corrupt': 2,
#  'best': 1,
#  'subject': 2,
#  'said': 1,
#  'temptation': 3,
#  "bett'ring": 2,
#  'away': 2,
#  'afloat': 2,
#  'bier': 1,
#  'madding': 2,
#  'wilful-slow': 3,
#  'mud': 1,
#  'score': 1,
#  'finger': 2,
#  'pebbled': 2,
#  'scorn': 1,
#  'drawn': 1,
#  'enlighten': 3,
#  'preserve': 2,
#  'warrior': 2,
#  'we': 1,
#  'men': 1,
#  'terms': 1,
#  'parallels': 3,
#  'nature': 2,
#  'weak': 1,
#  'ignorance': 3,
#  'authorizing': 4,
#  'disdaineth': 3,
#  'wear': 1,
#  'diest': 1,
#  'news': 1,
#  'debt': 1,
#  'pity': 2,
#  'foes': 1,
#  'goddess': 2,
#  'accident': 3,
#  'disdain': 2,
#  'fault': 1,
#  'ill': 1,
#  'against': 2,
#  'brag': 1,
#  'receives': 2,
#  'faces': 2,
#  'exceeds': 2,
#  'expense': 2,
#  'groans': 1,
#  'asked': 1,
#  'vexed': 1,
#  'honouring': 3,
#  'burthen': 2,
#  'height': 1,
#  'hers': 1,
#  'prone': 1,
#  'springs': 1,
#  'trust': 1,
#  'heals': 1,
#  'speak': 1,
#  'petty': 2,
#  'unhappily': 4,
#  'puts': 1,
#  'eager': 2,
#  'time-bettering': 4,
#  'exceeded': 3,
#  'three': 1,
#  'been': 1,
#  'particulars': 4,
#  'twain': 1,
#  'presagers': 3,
#  'interest': 3,
#  'incertainty': 4,
#  'privilege': 3,
#  'lovely': 2,
#  'thrice': 1,
#  'idol': 2,
#  'life': 1,
#  "brav'ry": 2,
#  'easy': 2,
#  'erred': 1,
#  'drugs': 1,
#  'maladies': 3,
#  'feedst': 1,
#  'decrepit': 3,
#  'dote': 1,
#  'child': 1,
#  'catch': 1,
#  'doth': 1,
#  'erst': 1,
#  'gracious': 2,
#  'play': 1,
#  'physician': 3,
#  'east': 1,
#  'weret': 2,
#  'air': 1,
#  'lesser': 2,
#  'ugly': 2,
#  'near': 1,
#  'suppose': 2,
#  'aid': 1,
#  'voice': 1,
#  'weakens': 2,
#  'recured': 2,
#  'is': 1,
#  'putst': 1,
#  'it': 1,
#  'defeated': 2,
#  'shame': 1,
#  'to-morrow': 3,
#  'splendour': 2,
#  'in': 1,
#  'bounteous': 3,
#  'if': 1,
#  'grown': 1,
#  'wooing': 2,
#  'memorial': 4,
#  'awakes': 2,
#  'cools': 1,
#  'patent': 2,
#  'suggest': 2,
#  'make': 1,
#  'wound': 1,
#  "lords'": 1,
#  'beside': 2,
#  'bosoms': 2,
#  "th'": 1,
#  'several': 3,
#  'grows': 1,
#  'entitled': 3,
#  'lusty': 2,
#  'fairly': 2,
#  'oersways': 2,
#  'indigest': 3,
#  'tops': 1,
#  'evil': 2,
#  'hand': 1,
#  'delight': 2,
#  'supposing': 3,
#  'jealous': 2,
#  'bequest': 2,
#  'blamed': 1,
#  'tune': 1,
#  'censures': 2,
#  'kept': 1,
#  'thy': 1,
#  'singleness': 3,
#  'askance': 2,
#  'possessed': 2,
#  'humble': 2,
#  'inherit': 3,
#  'ocean': 2,
#  'ragged': 2,
#  'fulness': 2,
#  'greatest': 1,
#  'incapable': 4,
#  'mother': 2,
#  'hearts': 1,
#  'the': 1,
#  'yours': 1,
#  'left': 1,
#  'just': 1,
#  'wasteful': 2,
#  'yea': 1,
#  "poet's": 2,
#  'unfair': 2,
#  'repose': 2,
#  'verses': 2,
#  'maketh': 2,
#  'farther': 2,
#  'swears': 1,
#  'prognosticate': 4,
#  'plight': 1,
#  'yet': 1,
#  'succeeding': 3,
#  'vices': 2,
#  'adding': 2,
#  'strangle': 2,
#  'keepst': 1,
#  'dearer': 2,
#  'compeers': 2,
#  'strains': 1,
#  'had': 1,
#  'counted': 2,
#  'alchemy': 3,
#  'belongs': 2,
#  'beloved': 3,
#  'prison': 2,
#  'hap': 1,
#  'pitiful': 3,
#  'save': 1,
#  'gave': 1,
#  "others'": 2,
#  'oerpressed': 2,
#  'dignity': 3,
#  'reviewest': 3,
#  'birth': 1,
#  'wanting': 2,
#  'shadow': 2,
#  'dreams': 1,
#  "picture's": 2,
#  'desire': 2,
#  'brought': 1,
#  "feed'st": 1,
#  'gift': 1,
#  'new-found': 2,
#  'vilest': 2,
#  'offices': 3,
#  'night': 1,
#  'hung': 1,
#  'antique': 2,
#  'dyers': 2,
#  'right': 1,
#  'old': 1,
#  'flatter': 2,
#  'all-oblivious': 4,
#  'deaf': 1,
#  'short-numbered': 3,
#  'dead': 1,
#  'born': 1,
#  'dear': 1,
#  'altered': 2,
#  'bore': 1,
#  'guess': 1,
#  'creep': 1,
#  'enemies': 3,
#  'for': 1,
#  "bosom's": 2,
#  'rehearse': 2,
#  'comments': 2,
#  'foe': 1,
#  'denied': 2,
#  'who': 1,
#  'bold': 1,
#  'burn': 1,
#  'divining': 3,
#  'forgetst': 2,
#  'shifting': 2,
#  'losing': 2,
#  'all-tyrant': 3,
#  'peep': 1,
#  'disdains': 2,
#  'shaken': 2,
#  'proceed': 2,
#  'theirs': 1,
#  'coral': 2,
#  'haply': 2,
#  'frailer': 2,
#  'o': 1,
#  'despair': 2,
#  'cherish': 2,
#  'commit': 2,
#  'lacked': 1,
#  'bath': 1,
#  'raised': 1,
#  'faint': 1,
#  'whats': 1,
#  'presence': 2,
#  'civil': 2,
#  'pays': 1,
#  'tract': 1,
#  'bound': 1,
#  'son': 1,
#  'down': 1,
#  'lies': 1,
#  'refined': 2,
#  "pour'st": 1,
#  'methods': 2,
#  'strangely': 2,
#  'despised': 2,
#  'jealousy': 3,
#  'sovereign': 3,
#  'fight': 1,
#  'virgin': 2,
#  'way': 1,
#  'call': 1,
#  'was': 1,
#  'war': 1,
#  'happy': 2,
#  'head': 1,
#  'perfumes': 2,
#  'form': 1,
#  'statute': 2,
#  'crown': 1,
#  'becoming': 3,
#  'anothers': 3,
#  'forgetful': 3,
#  'fore': 1,
#  'heinous': 2,
#  'pricked': 1,
#  "slander's": 2,
#  'hear': 1,
#  'odours': 2,
#  'learned': 2,
#  'astonished': 3,
#  'blindness': 2,
#  'removed': 2,
#  'true': 1,
#  'fort': 1,
#  'absent': 2,
#  'lilies': 2,
#  'captive': 2,
#  'extremity': 4,
#  "for't": 1,
#  'bids': 1,
#  'ruined': 1,
#  'crystal': 2,
#  'unfathered': 3,
#  'adore': 2,
#  'anew': 2,
#  'engraft': 2,
#  'bide': 1,
#  'latch': 1,
#  'trim': 1,
#  'disgrace': 2,
#  'ornaments': 3,
#  'up': 1,
#  'nought': 1,
#  'sinful': 2,
#  'steep-up': 2,
#  "beauty's": 2,
#  'huswife': 2,
#  'sometime': 2,
#  'subsist': 2,
#  'shines': 1,
#  'reproving': 3,
#  'check': 1,
#  'posting': 2,
#  'willingly': 3,
#  'looked': 1,
#  'dying': 2,
#  'no': 2,
#  'excel': 2,
#  "lov'st": 1,
#  'actor': 2,
#  'tis': 1,
#  'thriftless': 2,
#  'despising': 3,
#  'falsely': 2,
#  'papers': 2,
#  'tie': 1,
#  'vanished': 2,
#  'smell': 1,
#  'eternity': 4,
#  'picture': 2,
#  'neer-cloying': 3,
#  'intend': 2,
#  'phoenix': 2,
#  'savage': 2,
#  'dies': 1,
#  'welcome': 2,
#  'first-born': 2,
#  'present-absent': 4,
#  'fell': 1,
#  'reign': 1,
#  'rolling': 2,
#  'pierced': 1,
#  'died': 1,
#  'wrackful': 2,
#  'to-day': 1,
#  'longer': 2,
#  'blushing': 2,
#  'daily': 2,
#  'beds': 1,
#  'cheater': 2,
#  'teeth': 1,
#  "dian's": 2,
#  'laws': 1,
#  'restored': 2,
#  'songs': 1,
#  'whoever': 3,
#  "perceiv'st": 2,
#  'souls': 1,
#  'vermilion': 3,
#  'engrafted': 3,
#  'leads': 1,
#  'robbing': 2,
#  'slandered': 2,
#  'idolatry': 4,
#  'abundant': 3,
#  'retention': 3,
#  'mounted': 2,
#  'praises': 2,
#  'universe': 3,
#  'father': 2,
#  'pen': 1,
#  'vex': 1,
#  'charge': 1,
#  'praised': 1,
#  'lilys': 2,
#  'suffered': 2,
#  'addeth': 2,
#  'furrows': 2,
#  'shoot': 1,
#  'strumpeted': 3,
#  'greeing': 2,
#  'string': 1,
#  'advantage': 3,
#  'drudge': 1,
#  'fleece': 1,
#  'votary': 3,
#  'mourn': 1,
#  'advised': 2,
#  'locked': 1,
#  'trouble': 2,
#  'feeble': 2,
#  'cool': 1,
#  "soul's": 1,
#  'perceived': 2,
#  'clouds': 1,
#  'level': 2,
#  'tear': 1,
#  'die': 1,
#  'dig': 1,
#  "best'": 1,
#  'leave': 1,
#  'excellence': 3,
#  'quick': 1,
#  'prevent': 2,
#  'brave': 1,
#  'says': 1,
#  'fearing': 2,
#  "offender's": 3,
#  'double-vantage': 4,
#  'sigh': 1,
#  'wherefore': 2,
#  'cost': 1,
#  'patient': 2,
#  'fear': 1,
#  'drinks': 1,
#  'hymn': 1,
#  "fleet'st": 1,
#  'curse': 1,
#  'appear': 2,
#  'battring': 2,
#  'heres': 1,
#  'assistance': 3,
#  'contracted': 3,
#  'favour': 2,
#  'pleased': 1,
#  'suspect': 2,
#  'goes': 1,
#  'oer': 1,
#  'appeal': 2,
#  'filled': 1,
#  "april's": 2,
#  'prescriptions': 3,
#  'wail': 1,
#  'honour': 1,
#  'clerk': 1,
#  'water': 2,
#  'entertain': 3,
#  'alone': 2,
#  'appears': 2,
#  'change': 1,
#  'blunter': 2,
#  'boy': 1,
#  'boast': 1,
#  'root': 1,
#  'guilty': 2,
#  'bow': 1,
#  'spheres': 1,
#  'recounting': 3,
#  'treasure': 2,
#  'love': 1,
#  'humour': 1,
#  'tempteth': 2,
#  'bloody': 2,
#  'withal': 2,
#  'betraying': 3,
#  'surmount': 2,
#  'swallowed': 2,
#  "suff'ring": 2,
#  "o'erworn": 2,
#  'swayst': 1,
#  'wealth': 1,
#  'prove': 1,
#  'sake': 3,
#  'confounded': 3,
#  'angry': 2,
#  'give': 1,
#  'only': 2,
#  "batt'ring": 2,
#  'wrongs': 1,
#  'live': 1,
#  'going': 2,
#  'prey': 1,
#  'memory': 3,
#  'scope': 1,
#  'forced': 1,
#  'loving': 2,
#  "love's": 1,
#  'fierce': 1,
#  'riot': 2,
#  'sessions': 2,
#  'towers': 2,
#  'neglected': 3,
#  'acceptable': 4,
#  "strength's": 1,
#  'drown': 1,
#  'everywhere': 3,
#  'virtue': 2,
#  'stain': 1,
#  'epitaph': 3,
#  'fly': 1,
#  'impair': 2,
#  'sheds': 1,
#  'car': 1,
#  'soul': 1,
#  'purge': 1,
#  'hardest': 2,
#  'sour': 1,
#  'can': 1,
#  'believed': 2,
#  'making': 2,
#  "prevent'st": 2,
#  'deceased': 2,
#  'breeds': 1,
#  'unfolding': 3,
#  'heart': 1,
#  'dedicated': 1,
#  "servant's": 2,
#  'respose': 2,
#  'figure': 2,
#  'predict': 2,
#  'sense': 1,
#  'distillation': 4,
#  ...}

# %%
save_file = open(SYLL_DICT, 'rb')
syll_dict = pickle.load(save_file)
save_file.close()
syll_dict['children'] = 2
print len(syll_dict)

save_file = open(SYLL_DICT, 'wb')
pickle.dump(syll_dict, save_file)
save_file.close()

save_file = open(STRESS_DICT, 'rb')
stress_dict = pickle.load(save_file)
save_file.close()
stress_dict["children"] = 0
print len(stress_dict)

save_file = open(STRESS_DICT, 'wb')
pickle.dump(stress_dict, save_file)
save_file.close()
# Out:
# 3192
# 3192

# %%
print syll_dict
# Out:
# {'fawn': 1, 'pardon': 2, 'yellow': 2, 'four': 1, 'hath': 1, 'sleep': 1, "friend's": 1, 'hanging': 2, 'mansion': 2, 'appetite': 3, 'captain': 2, 'hate': 1, 'poorly': 2, 'whose': 1, 'feeding': 2, 'effectually': 5, 'granting': 2, 'sweetest': 2, 'presents': 2, 'whatsoever': 4, 'under': 2, 'lord': 1, 'sorry': 2, 'pride': 1, 'sway': 1, 'worth': 1, 'frowns': 1, 'discased': 2, 'dispense': 2, 'hadst': 1, 'inhearse': 2, "women's": 2, 'every': 3, 'foul': 1, 'nourished': 2, "o'er-read": 2, 'uttering': 3, 'prize': 1, 'sunk': 1, 'graced': 1, 'succession': 3, 'graces': 1, 'triumph': 2, 'enjoy': 2, 'charter': 2, 'force': 1, 'tired': 1, 'razed': 1, 'out-going': 3, 'tires': 1, 'crave': 1, 'persuade': 2, 'down-rased': 2, 'esteem': 2, 'quill': 1, 'even': 2, 'beated': 2, 'evermore': 3, 'hide': 1, "ne'er": 1, 'solemn': 2, 'thunder': 2, 'fingers': 2, 'liberty': 3, "gild'st": 1, 'worser': 2, 'wakened': 2, 'above': 2, 'matcheth': 2, 'new': 1, 'increasing': 1, 'ever': 2, 'told': 1, 'deemed': 1, 'sinks': 1, 'never': 2, 'here': 1, 'herd': 1, 'beck': 1, "sweet'st": 1, 'pursuit': 2, 'active': 2, 'quite': 1, 'a-doting': 3, 'dry': 1, 'resty': 2, 'substance': 2, 'attending': 3, 'leaves': 1, 'climbed': 1, 'credit': 2, 'smoke': 1, 'permit': 2, 'bettered': 2, 'mistake': 2, 'settled': 2, 'golden': 2, 'swearing': 2, 'divide': 2, 'blessed-fair': 3, 'sorrows': 2, 'patience': 2, 'stern': 1, 'glance': 1, "light's": 1, 'plot': 1, 'would': 1, 'crowning': 2, "world's": 1, 'junes': 1, 'music': 2, 'therefore': 2, 'survive': 2, 'gilding': 2, 'tell': 1, 'breathe': 1, 'leese': 1, 'unbless': 2, 'holy': 2, 'wary': 2, 'brings': 1, 'muse': 1, 'hurt': 1, 'grief': 1, 'glass': 1, 'warm': 1, 'former': 4, 'excellent': 3, 'continual': 4, 'ward': 1, 'hold': 1, 'striving': 2, 'must': 1, 'shoot': 1, 'join': 1, 'room': 1, 'err': 1, 'rights': 1, 'work': 1, 'eclipse': 2, 'roof': 1, 'meadows': 2, 'ere': 1, 'sharp': 1, 'leaped': 1, 'dost': 1, 'revenues': 3, 'root': 1, 'example': 3, 'shook': 1, 'fresher': 1, 'wane': 1, 'unjust': 2, 'impair': 2, "wand'rest": 2, 'want': 1, 'appearance': 3, 'story': 2, 'returned': 2, 'ceremony': 4, "consum'st": 2, 'gusts': 1, 'provide': 2, 'dignifies': 3, 'travel': 2, 'feature': 2, 'wights': 1, 'how': 1, 'hot': 1, 'writers': 2, 'answer': 2, 'gate': 1, 'dignified': 3, "o'er-snowed": 2, 'blanks': 1, 'beauty': 2, 'after': 2, 'hence': 1, 'wrong': 1, 'lay': 1, 'lap': 1, 'wronk': 1, "grow'st": 1, "rud'st": 1, 'revolt': 2, 'greet': 1, 'purging': 2, 'wink': 1, 'maintain': 2, 'green': 1, 'keeps': 1, 'alack': 2, 'mightier': 2, 'wouldst': 1, 'wind': 1, 'bed-vow': 2, 'determinate': 4, 'couplement': 3, 'after-loss': 3, 'office': 2, 'consent': 2, 'choose': 1, 'profaned': 2, 'sickly': 2, 'fortify': 3, 'ghastly': 2, 'budding': 2, "bestow'st": 2, 'wrought': 1, 'before': 2, 'wilt': 1, 'thrust': 1, 'better': 2, 'fade': 1, 'carve': 1, 'hidden': 2, 'possessing': 3, 'then': 1, 'them': 1, 'blots': 1, 'weakness': 2, 'thee': 1, "truth's": 1, 'break': 1, "winter's": 2, 'diseased': 2, 'they': 1, 'glazed': 1, "lovers'": 2, 'silver': 2, 'shadows': 2, 'rhetoric': 3, 'brightness': 2, 'slavery': 3, 'rocks': 1, 'herald': 2, 'victories': 3, 'each': 1, 'wantonly': 3, 'dulness': 2, 'went': 1, 'side': 1, 'luck': 1, 'true-telling': 3, 'woes': 1, 'concord': 2, "'will'": 1, 'taught': 1, 'forgot': 2, 'misprision': 3, 'whit': 1, 'truant': 2, 'array': 2, 'borne': 1, 'contend': 2, 'silvered': 2, 'decree': 2, 'god': 1, 'forty': 2, 'moiety': 3, 'content': 2, 'laid': 1, 'heart-inflaming': 4, 'unseen': 2, 'heavenly': 3, 'got': 1, 'marigold': 3, 'forth': 1, 'assured': 2, 'fadeth': 2, 'hang': 1, 'eternal': 3, 'given': 2, 'free': 1, 'mourning': 2, 'small': 1, 'bestow': 2, 'whereupon': 3, 'rain': 1, 'basest': 2, 'crowned': 1, 'mistress': 2, 'knit': 1, "receiv'st": 2, 'created': 2, 'days': 1, 'ordering': 3, 'renew': 2, 'tempting': 2, 'potions': 2, 'loud': 1, 'ruinate': 3, 'penury': 3, 'separable': 4, 'untutored': 3, 'already': 3, 'hearsay': 2, "'greeing": 2, 'maladies': 3, 'hearing': 2, 'workings': 2, 'featured': 2, ...

# %%
syll_dict['effectually'] = 4
syll_dict['continual'] = 3
syll_dict['master'] = 2
syll_dict['lover'] = 2
syll_dict['gentle'] = 2
syll_dict['beloved'] = 3
syll_dict['losing'] = 2
syll_dict['everywhere'] = 3
syll_dict['rebel'] = 2
syll_dict['desert'] = 2
syll_dict['refuse'] = 2
syll_dict['render'] = 2
syll_dict['elder'] = 2
syll_dict['bower'] = 2
syll_dict['travail'] = 2
syll_dict['tender'] = 2
syll_dict['salve'] = 1
syll_dict['tyrant'] = 2
syll_dict['progress'] = 2
syll_dict['present'] = 2
syll_dict['raven'] = 2
syll_dict['record'] = 2

# %%
print len(syll_dict)

save_file = open(SYLL_DICT, 'wb')
pickle.dump(syll_dict, save_file)
save_file.close()
# Out:
# 3190

# %%
stess_dict = make_stress_dict(all_lines, syll_dict)

# %%
print len(stess_dict)
save_file = open(STRESS_DICT, 'wb')
pickle.dump(stess_dict, save_file)
save_file.close()
# Out:
# 3139

# %%
syll_dict['progress']
# Out:
# 2

# %%
save_file = open(SYLL_DICT, 'rb')
syll_dict = pickle.load(save_file)
save_file.close()
print len(syll_dict)
# Out:
# 3319

# %%
save_file = open(SYLL_DICT, 'rb')
syll_dict = pickle.load(save_file)
save_file.close()
syll_dict['children'] = 2
print len(syll_dict)

save_file = open(SYLL_DICT, 'wb')
pickle.dump(syll_dict, save_file)
save_file.close()
# Out:
# 3319
