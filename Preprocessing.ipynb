# %%
import numpy as np

SONNET_LINES = 14
NUM_QUATRAINS = 3
QUATRAIN_LINES = 4
COUPLET_LINES = 2
NUM_SHKSP_SONNETS = 151

PUNCTUATION = [',', ':', '.', ';', '?', '!', '(', ')']

SYLL_DICT = 'syll_dict.p'

############################################################
# Read in raw sonnets.
############################################################

def shksp_raw(filename='shakespeare.txt'):
    seqs = np.loadtxt(filename, delimiter='\n', dtype='str')
    return seqs

############################################################
# Different tokenizers per line.
############################################################

# simple_token1:
#   Checks back of each line for punctuation and if found, 
#   replaces with a single token of the punctuation and a 
#   newline character. Punctuation within line is attatched
#   to word on left.
def simple_token1(line):
    line = line.lower().lstrip().rstrip()
    line = line.split(' ')
    # Handle punctuation at end of line.
    last_word = list(line[-1])
    del line[-1]
    if last_word[-1] in PUNCTUATION:
        tmp = last_word[-1]
        del last_word[-1]
        line.append(''.join(last_word))
        line.append(tmp + '\n')
    else:
        line.append(''.join(last_word))
    return line

# simple_token2:
#   All punctuation are attached to word on left, no 
#   newline characters.
def simple_token2(line):
    line = line.lower().lstrip().rstrip()
    line = line.split(' ')
    return line

# simple_token3:
#   All punctuation attached to word on left. Newline
#   characters for each line.
def simple_token3(line):
    line = line.lower().lstrip().rstrip()
    line = line.split(' ')
    return line + ['\n']

# simple_token4:
#   Remove all punctuation, no newline character.
def simple_token4(line):
    line = line.lower().lstrip().rstrip()
    for punc in PUNCTUATION:
        line = line.replace(punc, '')
    line = line.split(' ')
    return line

############################################################
# Preprocess Shakespeare sonnets.
############################################################

def shksp_per_sonnet(tokenizer, filename='shakespeare.txt'):
    raw = shksp_raw(filename)
    sequences = []
    cursor = 0
    for sonnet in range(NUM_SHKSP_SONNETS):
        # Skip first line which is a number.
        cursor += 1
        # Setup sequence.
        seq = []
        for i in range(SONNET_LINES):
            seq += tokenizer(raw[cursor])
            cursor += 1
        sequences.append(seq)
    return sequences

def shksp_per_line(tokenizer, filename='shakespeare.txt'):
    raw = shksp_raw(filename)
    sequences = []
    cursor = 0
    for sonnet in range(NUM_SHKSP_SONNETS):
        # Skip first line which is a number.
        cursor += 1
        for i in range(SONNET_LINES):
            sequences.append(tokenizer(raw[cursor]))
            cursor += 1
    return sequences

def shksp_quatrains_and_couplets(tokenizer, filename='shakespeare.txt'):
    raw = shksp_raw(filename)
    quatrains = []
    couplets = []
    cursor = 0
    for sonnet in range(NUM_SHKSP_SONNETS):
        cursor += 1
        couplet = []
        for quatrain in range(NUM_QUATRAINS):
            quatrain = []
            for line in range(QUATRAIN_LINES):
                quatrain += tokenizer(raw[cursor])
                cursor += 1
            quatrains.append(quatrain)
        for line in range(COUPLET_LINES):
            couplet += tokenizer(raw[cursor])
            cursor += 1
        couplets.append(couplet)
    return quatrains, couplets

def shksp_quatrain_couplets_line(tokenizer, filename='shakespeare.txt'):
    raw = shksp_raw(filename)
    quatrains = []
    couplets = []
    cursor = 0
    for sonnet in range(NUM_SHKSP_SONNETS):
        cursor += 1
        couplet = []
        for quatrain in range(NUM_QUATRAINS):
            for line in range(QUATRAIN_LINES):
                quatrains.append(tokenizer(raw[cursor]))
                cursor += 1
        for line in range(COUPLET_LINES):
            couplets.append(tokenizer(raw[cursor]))
            cursor += 1
    return quatrains, couplets

# %%
############################################################
# Generate from trained models.
############################################################
def gen_txt(trans, emiss, init, word_map, length, space_symb=' '):
    # Verify that the model is functional and setup.
    num_states = len(trans)
    num_words = len(emiss[0])
    assert (num_states == len(trans[0])), 'Transition matrix is not square.'
    assert (num_states == len(emiss)), 'Emission matrix not correct dimensions.'
    
    # Prepare to iterate for words.
    build = ''
    curr_state = np.random.choice(num_states, p=init)
    
    # Build the sequence.
    for i in range(length):
        nxt_token = np.random.choice(num_words, p=emiss[curr_state])
        build += word_map[nxt_token] + space_symb
        curr_state = np.random.choice(num_states, p=trans[curr_state])
    return build

# %%
class HMM:

    def __init__(self, num_states):

        self.D = 0 # num of unique observations
        self.L = num_states # num of hidden states

        self.token_dict = {} # map of integers to tokens

        self.A = None # transition (row: from; col: to), 0-indexed
        self.PI = None # initial state distribution, 0-indexed
        self.O = None # observation (row: state; col: observation), 0-indexed

    def train(self, data, epsilon=0.001, scaling=True):
        X = self.registerObs(data)
        L = self.L
        D = self.D

        # Initialize Matrices
        self.A = self.normalize(np.random.rand(L, L))
        self.PI = self.normalize(np.random.rand(L))
        self.O = self.normalize(np.random.rand(L, D))


        norm_arr = []
        iterations = 0

        while (True):
            iterations += 1
            # E Step
            alphas_arr = []
            betas_arr = []
            for seq in X:
                alphas, betas = self.forwardBackward(seq, scaling)
                alphas_arr.append(alphas)
                betas_arr.append(betas)

            # M step (Computes marginals + Updates)
            change_norm = self.update(X, alphas_arr, betas_arr)
            norm_arr.append(change_norm)

            # Stopping Condition
            if len(norm_arr) > 1 and norm_arr[-1] / norm_arr[0] < epsilon:
                print iterations
                break

        print h.PI
        print h.A
        print h.O

    """ Registers observations as integers and returns data transformed into
    integers. """
    def registerObs(self, data):
        # Reset Variables
        self.D = 0
        self.token_dict = {}

        X = [] # data transformed into integers corresponding to tokens
        for seq in data:
            X_i = [] # this sequence transformed into integers
            for token in seq:
                if token not in self.token_dict:
                    self.token_dict[token] = self.D
                    self.D += 1
                X_i.append(self.token_dict[token])
            X.append(X_i)
        return X

    """ Makes all rows add up to 1 """
    @staticmethod
    def normalize(matrix):
        if len(matrix.shape) == 1:
            return matrix / matrix.sum()
        sums = matrix.sum(axis=1)
        return matrix / sums.reshape(sums.shape[0], 1)

    def forwardBackward(self, seq, scaling=True):
        """ This function computes alpha and beta values for a sequence
            using the Forward-Backward algorithm.
        """
        M = len(seq) # length of given sequence
        L = self.L # num of states

        alphas = np.zeros((M, L)) # row: position; col: state
        betas = np.zeros((M, L)) # row: position; col: state

        # FORWARD ALGORITHM
        for i in range(M): # For each observation
            for s in range(L): # For each state
                # Base case
                if i == 0:
                    alphas[i, s] = self.O[s, seq[0]] * self.PI[s]
                else:
                    sum = 0
                    # For each previous state
                    for prev in range(L):
                        sum += alphas[i-1, prev] * self.A[prev, s]
                    alphas[i, s] = sum * self.O[s, seq[i]]
            # Scaling
            if scaling:
                scale = np.sum(alphas[i])
                alphas[i] = alphas[i] / scale

        # BACKWARD ALGORITHM
        for i in reversed(range(M)): # For each observation
            for s in range(L): # For each state
                # Base case
                if i == M-1:
                    betas[i, s] = 1
                else:
                    # For each next state
                    for next in range(L):
                        betas[i, s] += betas[i+1, next] * \
                                       self.A[s, next] * self.O[next, seq[i+1]]
            # Scaling
            if scaling:
                scale = np.sum(betas[i])
                betas[i] = betas[i] / scale

        return (alphas, betas)

    def update(self, X, alphas_arr, betas_arr):
        L = self.L # num states
        D = self.D # num unique tokens

        # new matrices
        PI = np.zeros(self.PI.shape)
        A = np.zeros(self.A.shape)
        O = np.zeros(self.O.shape)

        # update O (emission matrix)
        for state in range(L):
            for token in range(D):
                numerator = 0
                denominator = 0
                for j in range(len(X)): # iterate over all sequences
                    seq = X[j]
                    alphas = alphas_arr[j]
                    betas = betas_arr[j]

                    # for each index in seq
                    for i in range(len(seq)):
                        # compute P(y_i = z)
                        top = alphas[i, state] * betas[i, state]
                        bot = alphas[i].dot(betas[i])
                        prob = top / bot

                        if seq[i] == token: # indicator function
                            numerator += prob
                        denominator += prob
                O[state, token] = numerator / denominator

        # Make sure numbers add up to 1
        O = self.normalize(O)

        # update PI (initial distribution matrix)
        for state in range(L):
            prob_sum = 0
            for j in range(len(X)): # iterate over all sequences
                seq = X[j]
                alphas = alphas_arr[j]
                betas = betas_arr[j]

                # compute P(y_0 = state)
                prob_sum += alphas[0, state] * betas[0, state] / \
                            alphas[0].dot(betas[0])
            PI[state] = prob_sum / len(X)
        # Make sure numbers add up to 1
        PI = self.normalize(PI)

        # Update A (transition matrix)
        for prev in range(L):
            for next in range(L):
                numerator = 0
                denominator = 0

                for j in range(len(X)): # iterate over all sequences
                    seq = X[j]
                    alphas = alphas_arr[j]
                    betas = betas_arr[j]

                    # for each index in seq excluding last index
                    for i in range(len(seq)-1):
                        # Compute P(y_i = prev, y_i+1 = next) and add to
                        # numerator
                        # Names: numerator_top, numerator_bottom
                        num_top = alphas[i, prev] * self.O[next, seq[i+1]] * \
                               self.A[prev, next] * betas[i+1, next]
                        num_bot = 0
                        # SHOULD BE PRECOMPUTED (FIX LATER)
                        for prev_state in range(L):
                            for next_state in range(L):
                                num_bot += alphas[i, prev_state] * \
                                        self.O[next_state, seq[i+1]] * \
                                        self.A[prev_state, next_state] * \
                                        betas[i+1, next_state]
                        numerator += num_top / num_bot

                        # Compute P(y_i = b) and add to denominator
                        # Names: denominator_top, denominator_bottom
                        denom_top = alphas[i, prev] * betas[i, prev]
                        denom_bot = alphas[i].dot(betas[i])

                        denominator += denom_top / denom_bot

                # UPDATE A_{prev, next}
                A[prev, next] = numerator / denominator

        # Make sure numbers add up to 1
        A = self.normalize(A)

        # Calculate norm of change
        # Frobenius norm of the differences between update and previous matrices
        change_norm = np.linalg.norm(self.A - A) + np.linalg.norm(self.O - O) \
                      + np.linalg.norm(self.PI - PI)

        # update matrices
        self.O = O
        self.PI = PI
        self.A = A

        return change_norm

# %%
# Test training.
q, c = shksp_quatrain_couplets_line(simple_token2)
q_hmm = HMM(20)

# %%
from wordnik import *
apiUrl = 'http://api.wordnik.com/v4'
apiKey = '552b2562693245ea105020d08c904c58324d0d2b793995895'
client = swagger.ApiClient(apiKey, apiUrl)

wordApi = WordApi.WordApi(client)
example1 = wordApi.getHyphenation('dsad')
example2 = wordApi.getHyphenation('dafe')

# %%
# Set up pickle dictionary for syllable processing. 
# DO NOT RUN AFTER COMPLETING DICTIONARY!
import pickle
syll_dict = {'from' : 1}
save_file = open(SYLL_DICT, 'wb')
pickle.dump(syll_dict, save_file)
save_file.close()

# %%
# Method for assisting in creating syllables dict.
def make_syll_dict(lines):
    # Setup API connections.
    apiUrl = 'http://api.wordnik.com/v4'
    apiKey = '552b2562693245ea105020d08c904c58324d0d2b793995895'
    client = swagger.ApiClient(apiKey, apiUrl)
    wordApi = WordApi.WordApi(client)
    
    # Read in old dictionary.
    save_file = open(SYLL_DICT, 'rb')
    syll_dict = pickle.load(save_file)
    save_file.close()
    
    for line in lines:
        for word in line:
            if syll_dict.get(word) == None:
                try_api = wordApi.getHyphenation(word)
                if try_api != None:
                    syll_dict[word] = len(try_api)
                else:
                    print word, ':', line
                    count = input()
                    syll_dict[word] = count
        save_file = open(SYLL_DICT, 'wb')
        pickle.dump(syll_dict, save_file)
        save_file.close()
        
    return syll_dict

# %%
all_lines = shksp_per_line(simple_token4)
print len(all_lines)
# Out:
# 2114

# %%
make_syll_dict(all_lines)
# Out:
# bones : ['when', 'that', 'churl', 'death', 'my', 'bones', 'with', 'dust', 'shall', 'cover']
# 1
# re-survey : ['and', 'shalt', 'by', 'fortune', 'once', 'more', 're-survey']
# 3
# bett'ring : ['compare', 'them', 'with', 'the', "bett'ring", 'of', 'the', 'time']
# 2
# outstripped : ['and', 'though', 'they', 'be', 'outstripped', 'by', 'every', 'pen']
# 2
# exceeded : ['exceeded', 'by', 'the', 'height', 'of', 'happier', 'men']
# 3
# 'had : ["'had", 'my', "friend's", 'muse', 'grown', 'with', 'this', 'growing', 'age']
# 1
# friend's : ["'had", 'my', "friend's", 'muse', 'grown', 'with', 'this', 'growing', 'age']
# 1
# dearer : ['a', 'dearer', 'birth', 'than', 'this', 'his', 'love', 'had', 'brought']
# 2
# brought : ['a', 'dearer', 'birth', 'than', 'this', 'his', 'love', 'had', 'brought']
# 1
# ranks : ['to', 'march', 'in', 'ranks', 'of', 'better', 'equipage']
# 1
# died : ['but', 'since', 'he', 'died', 'and', 'poets', 'better', 'prove']
# 1
# poets : ['but', 'since', 'he', 'died', 'and', 'poets', 'better', 'prove']
# 2
# i'll : ['theirs', 'for', 'their', 'style', "i'll", 'read', 'his', 'for', 'his', "love'"]
# 1
# love' : ['theirs', 'for', 'their', 'style', "i'll", 'read', 'his', 'for', 'his', "love'"]
# 1
# tops : ['flatter', 'the', 'mountain', 'tops', 'with', 'sovereign', 'eye']
# 1
# kissing : ['kissing', 'with', 'golden', 'face', 'the', 'meadows', 'green']
# 2
# meadows : ['kissing', 'with', 'golden', 'face', 'the', 'meadows', 'green']
# 2
# streams : ['gilding', 'pale', 'streams', 'with', 'heavenly', 'alchemy']
# 1
# basest : ['anon', 'permit', 'the', 'basest', 'clouds', 'to', 'ride']
# 2
# splendour : ['with', 'all', 'triumphant', 'splendour', 'on', 'my', 'brow']
# 2
# disdaineth : ['yet', 'him', 'for', 'this', 'my', 'love', 'no', 'whit', 'disdaineth']
# 3
# suns : ['suns', 'of', 'the', 'world', 'may', 'stain', 'when', "heaven's", 'sun', 'staineth']
# 1
# staineth : ['suns', 'of', 'the', 'world', 'may', 'stain', 'when', "heaven's", 'sun', 'staineth']
# 2
# o'ertake : ['to', 'let', 'base', 'clouds', "o'ertake", 'me', 'in', 'my', 'way']
# 2
# brav'ry : ['hiding', 'thy', "brav'ry", 'in', 'their', 'rotten', 'smoke']
# 2
# storm-beaten : ['to', 'dry', 'the', 'rain', 'on', 'my', 'storm-beaten', 'face']
# 3
# heals : ['that', 'heals', 'the', 'wound', 'and', 'cures', 'not', 'the', 'disgrace']
# 1
# cures : ['that', 'heals', 'the', 'wound', 'and', 'cures', 'not', 'the', 'disgrace']
# 1
# offender's : ["th'", "offender's", 'sorrow', 'lends', 'but', 'weak', 'relief']
# 3
# bears : ['to', 'him', 'that', 'bears', 'the', 'strong', "offence's", 'cross']
# 1
# offence's : ['to', 'him', 'that', 'bears', 'the', 'strong', "offence's", 'cross']
# 3
# tears : ['ah', 'but', 'those', 'tears', 'are', 'pearl', 'which', 'thy', 'love', 'sheds']
# 1
# sheds : ['ah', 'but', 'those', 'tears', 'are', 'pearl', 'which', 'thy', 'love', 'sheds']
# 1
# grieved : ['no', 'more', 'be', 'grieved', 'at', 'that', 'which', 'thou', 'hast', 'done']
# 1
# roses : ['roses', 'have', 'thorns', 'and', 'silver', 'fountains', 'mud']
# 2
# thorns : ['roses', 'have', 'thorns', 'and', 'silver', 'fountains', 'mud']
# 1
# fountains : ['roses', 'have', 'thorns', 'and', 'silver', 'fountains', 'mud']
# 2
# eclipses : ['clouds', 'and', 'eclipses', 'stain', 'both', 'moon', 'and', 'sun']
# 3
# sweetest : ['and', 'loathsome', 'canker', 'lives', 'in', 'sweetest', 'bud']
# 2
# faults : ['all', 'men', 'make', 'faults', 'and', 'even', 'i', 'in', 'this']
# 1
# authorizing : ['authorizing', 'thy', 'trespass', 'with', 'compare']
# 4
# corrupting : ['my', 'self', 'corrupting', 'salving', 'thy', 'amiss']
# 3
# salving : ['my', 'self', 'corrupting', 'salving', 'thy', 'amiss']
# 2
# excusing : ['excusing', 'thy', 'sins', 'more', 'than', 'thy', 'sins', 'are']
# 3
# sins : ['excusing', 'thy', 'sins', 'more', 'than', 'thy', 'sins', 'are']
# 1
# robs : ['to', 'that', 'sweet', 'thief', 'which', 'sourly', 'robs', 'from', 'me']
# 1
# loves : ['although', 'our', 'undivided', 'loves', 'are', 'one']
# 1
# blots : ['so', 'shall', 'those', 'blots', 'that', 'do', 'with', 'me', 'remain']
# 1
# bewailed : ['lest', 'my', 'bewailed', 'guilt', 'should', 'do', 'thee', 'shame']
# 2
# fortune's : ['so', 'i', 'made', 'lame', 'by', "fortune's", 'dearest', 'spite']
# 2
# dearest : ['so', 'i', 'made', 'lame', 'by', "fortune's", 'dearest', 'spite']
# 2
# entitled : ['entitled', 'in', 'thy', 'parts', 'do', 'crowned', 'sit']
# 3
# engrafted : ['i', 'make', 'my', 'love', 'engrafted', 'to', 'this', 'store']
# 3
# despised : ['so', 'then', 'i', 'am', 'not', 'lame', 'poor', 'nor', 'despised']
# 2
# sufficed : ['that', 'i', 'in', 'thy', 'abundance', 'am', 'sufficed']
# 2
# pour'st : ['while', 'thou', 'dost', 'breathe', 'that', "pour'st", 'into', 'my', 'verse']
# 1
# thanks : ['o', 'give', 'thy', 'self', 'the', 'thanks', 'if', 'aught', 'in', 'me']
# 1
# who's : ['for', "who's", 'so', 'dumb', 'that', 'cannot', 'write', 'to', 'thee']
# 1
# rhymers : ['than', 'those', 'old', 'nine', 'which', 'rhymers', 'invocate']
# 2
# manners : ['o', 'how', 'thy', 'worth', 'with', 'manners', 'may', 'i', 'sing']
# 2
# deserv'st : ['that', 'due', 'to', 'thee', 'which', 'thou', "deserv'st", 'alone']
# 2
# teachest : ['and', 'that', 'thou', 'teachest', 'how', 'to', 'make', 'one', 'twain']
# 2
# praising : ['by', 'praising', 'him', 'here', 'who', 'doth', 'hence', 'remain']
# 2
# hadst : ['what', 'hast', 'thou', 'then', 'more', 'than', 'thou', 'hadst', 'before']
# 1
# receivest : ['then', 'if', 'for', 'my', 'love', 'thou', 'my', 'love', 'receivest']
# 3
# usest : ['i', 'cannot', 'blame', 'thee', 'for', 'my', 'love', 'thou', 'usest']
# 2
# blamed : ['but', 'yet', 'be', 'blamed', 'if', 'thou', 'thy', 'self', 'deceivest']
# 1
# deceivest : ['but', 'yet', 'be', 'blamed', 'if', 'thou', 'thy', 'self', 'deceivest']
# 3
# refusest : ['by', 'wilful', 'taste', 'of', 'what', 'thy', 'self', 'refusest']
# 2
# greater : ['and', 'yet', 'love', 'knows', 'it', 'is', 'a', 'greater', 'grief']
# 2
# hate's : ['to', 'bear', 'greater', 'wrong', 'than', "hate's", 'known', 'injury']
# 1
# spites : ['kill', 'me', 'with', 'spites', 'yet', 'we', 'must', 'not', 'be', 'foes']
# 1
# foes : ['kill', 'me', 'with', 'spites', 'yet', 'we', 'must', 'not', 'be', 'foes']
# 1
# wrongs : ['those', 'pretty', 'wrongs', 'that', 'liberty', 'commits']
# 1
# years : ['thy', 'beauty', 'and', 'thy', 'years', 'full', 'well', 'befits']
# 1
# befits : ['thy', 'beauty', 'and', 'thy', 'years', 'full', 'well', 'befits']
# 2
# follows : ['for', 'still', 'temptation', 'follows', 'where', 'thou', 'art']
# 2
# assailed : ['beauteous', 'thou', 'art', 'therefore', 'to', 'be', 'assailed']
# 2
# woos : ['and', 'when', 'a', 'woman', 'woos', 'what', "woman's", 'son']
# 1
# prevailed : ['will', 'sourly', 'leave', 'her', 'till', 'he', 'have', 'prevailed']
# 2
# mightst : ['ay', 'me', 'but', 'yet', 'thou', 'mightst', 'my', 'seat', 'forbear']
# 1
# seat : ['ay', 'me', 'but', 'yet', 'thou', 'mightst', 'my', 'seat', 'forbear']
# 1
# straying : ['and', 'chide', 'thy', 'beauty', 'and', 'thy', 'straying', 'youth']
# 2
# said : ['and', 'yet', 'it', 'may', 'be', 'said', 'i', 'loved', 'her', 'dearly']
# 1
# wailing : ['that', 'she', 'hath', 'thee', 'is', 'of', 'my', 'wailing', 'chief']
# 2
# offenders : ['loving', 'offenders', 'thus', 'i', 'will', 'excuse', 'ye']
# 3
# know'st : ['thou', 'dost', 'love', 'her', 'because', 'thou', "know'st", 'i', 'love', 'her']
# 1
# suff'ring : ["suff'ring", 'my', 'friend', 'for', 'my', 'sake', 'to', 'approve', 'her']
# 2
# here's : ['but', "here's", 'the', 'joy', 'my', 'friend', 'and', 'i', 'are', 'one']
# 1
# unrespected : ['for', 'all', 'the', 'day', 'they', 'view', 'things', 'unrespected']
# 3
# dreams : ['but', 'when', 'i', 'sleep', 'in', 'dreams', 'they', 'look', 'on', 'thee']
# 1
# shadows : ['then', 'thou', 'whose', 'shadow', 'shadows', 'doth', 'make', 'bright']
# 2
# shadow's : ['how', 'would', 'thy', "shadow's", 'form', 'form', 'happy', 'show']
# 2
# unseeing : ['when', 'to', 'unseeing', 'eyes', 'thy', 'shade', 'shines', 'so']
# 3
# nights : ['all', 'days', 'are', 'nights', 'to', 'see', 'till', 'i', 'see', 'thee']
# 1
# limits : ['from', 'limits', 'far', 'remote', 'where', 'thou', 'dost', 'stay']
# 2
# kills : ['but', 'ah', 'thought', 'kills', 'me', 'that', 'i', 'am', 'not', 'thought']
# 1
# lengths : ['to', 'leap', 'large', 'lengths', 'of', 'miles', 'when', 'thou', 'art', 'gone']
# 1
# miles : ['to', 'leap', 'large', 'lengths', 'of', 'miles', 'when', 'thou', 'art', 'gone']
# 1
# receiving : ['receiving', 'nought', 'by', 'elements', 'so', 'slow']
# 3
# elements : ['receiving', 'nought', 'by', 'elements', 'so', 'slow']
# 3
# badges : ['but', 'heavy', 'tears', 'badges', 'of', "either's", 'woe']
# 2
# present-absent : ['these', 'present-absent', 'with', 'swift', 'motion', 'slide']
# 4
# quicker : ['for', 'when', 'these', 'quicker', 'elements', 'are', 'gone']
# 2
# sinks : ['sinks', 'down', 'to', 'death', 'oppressed', 'with', 'melancholy']
# 1
# life's : ['until', "life's", 'composition', 'be', 'recured']
# 1
# recured : ['until', "life's", 'composition', 'be', 'recured']
# 2
# messengers : ['by', 'those', 'swift', 'messengers', 'returned', 'from', 'thee']
# 3
# returned : ['by', 'those', 'swift', 'messengers', 'returned', 'from', 'thee']
# 2
# recounting : ['of', 'thy', 'fair', 'health', 'recounting', 'it', 'to', 'me']
# 3
# picture's : ['mine', 'eye', 'my', 'heart', 'thy', "picture's", 'sight', 'would', 'bar']
# 2
# says : ['and', 'says', 'in', 'him', 'thy', 'fair', 'appearance', 'lies']
# 1
# impanelled : ['to', 'side', 'this', 'title', 'is', 'impanelled']
# 3
# tenants : ['a', 'quest', 'of', 'thoughts', 'all', 'tenants', 'to', 'the', 'heart']
# 2
# eye's : ['the', 'clear', "eye's", 'moiety', 'and', 'the', 'dear', "heart's", 'part']
# 1
# heart's : ['the', 'clear', "eye's", 'moiety', 'and', 'the', 'dear', "heart's", 'part']
# 1
# famished : ['when', 'that', 'mine', 'eye', 'is', 'famished', 'for', 'a', 'look']
# 2
# sighs : ['or', 'heart', 'in', 'love', 'with', 'sighs', 'himself', 'doth', 'smother']
# 1
# bids : ['and', 'to', 'the', 'painted', 'banquet', 'bids', 'my', 'heart']
# 1
# awakes : ['awakes', 'my', 'heart', 'to', "heart's", 'and', "eye's", 'delight']
# 2
# truest : ['each', 'trifle', 'under', 'truest', 'bars', 'to', 'thrust']
# 2
# wards : ['from', 'hands', 'of', 'falsehood', 'in', 'sure', 'wards', 'of', 'trust']
# 1
# jewels : ['but', 'thou', 'to', 'whom', 'my', 'jewels', 'trifles', 'are']
# 2
# trifles : ['but', 'thou', 'to', 'whom', 'my', 'jewels', 'trifles', 'are']
# 2
# locked : ['thee', 'have', 'i', 'not', 'locked', 'up', 'in', 'any', 'chest']
# 1
# proves : ['for', 'truth', 'proves', 'thievish', 'for', 'a', 'prize', 'so', 'dear']
# 1
# defects : ['when', 'i', 'shall', 'see', 'thee', 'frown', 'on', 'my', 'defects']
# 2
# called : ['called', 'to', 'that', 'audit', 'by', 'advised', 'respects']
# 1
# respects : ['called', 'to', 'that', 'audit', 'by', 'advised', 'respects']
# 2
# scarcely : ['and', 'scarcely', 'greet', 'me', 'with', 'that', 'sun', 'thine', 'eye']
# 2
# reasons : ['shall', 'reasons', 'find', 'of', 'settled', 'gravity']
# 2
# settled : ['shall', 'reasons', 'find', 'of', 'settled', 'gravity']
# 2
# travel's : ['when', 'what', 'i', 'seek', 'my', 'weary', "travel's", 'end']
# 2
# 'thus : ["'thus", 'far', 'the', 'miles', 'are', 'measured', 'from', 'thy', "friend'"]
# 1
# friend' : ["'thus", 'far', 'the', 'miles', 'are', 'measured', 'from', 'thy', "friend'"]
# 1
# plods : ['plods', 'dully', 'on', 'to', 'bear', 'that', 'weight', 'in', 'me']
# 1
# thrusts : ['that', 'sometimes', 'anger', 'thrusts', 'into', 'his', 'hide']
# 1
# answers : ['which', 'heavily', 'he', 'answers', 'with', 'a', 'groan']
# 2
# spurring : ['more', 'sharp', 'to', 'me', 'than', 'spurring', 'to', 'his', 'side']
# 2
# perfect'st : ['therefore', 'desire', 'of', "perfect'st", 'love', 'being', 'made']
# 2
# wilful-slow : ['since', 'from', 'thee', 'going', 'he', 'went', 'wilful-slow']
# 3
# up-locked : ['can', 'bring', 'him', 'to', 'his', 'sweet', 'up-locked', 'treasure']
# 2
# blunting : ['for', 'blunting', 'the', 'fine', 'point', 'of', 'seldom', 'pleasure']
# 2
# feasts : ['therefore', 'are', 'feasts', 'so', 'solemn', 'and', 'so', 'rare']
# 1
# stones : ['like', 'stones', 'of', 'worth', 'they', 'thinly', 'placed', 'are']
# 1
# placed : ['like', 'stones', 'of', 'worth', 'they', 'thinly', 'placed', 'are']
# 1
# special-blest : ['to', 'make', 'some', 'special', 'instant', 'special-blest']
# 3
# unfolding : ['by', 'new', 'unfolding', 'his', 'imprisoned', 'pride']
# 3
# imprisoned : ['by', 'new', 'unfolding', 'his', 'imprisoned', 'pride']
# 3
# lacked : ['being', 'had', 'to', 'triumph', 'being', 'lacked', 'to', 'hope']
# 1
# millions : ['that', 'millions', 'of', 'strange', 'shadows', 'on', 'you', 'tend']
# 2
# adonis : ['describe', 'adonis', 'and', 'the', 'counterfeit']
# 3
# imitated : ['is', 'poorly', 'imitated', 'after', 'you']
# 4
# helen's : ['on', "helen's", 'cheek', 'all', 'art', 'of', 'beauty', 'set']
# 2
# grecian : ['and', 'you', 'in', 'grecian', 'tires', 'are', 'painted', 'new']
# 2
# tires : ['and', 'you', 'in', 'grecian', 'tires', 'are', 'painted', 'new']
# 1
# odour : ['for', 'that', 'sweet', 'odour', 'which', 'doth', 'in', 'it', 'live']
# 2
# blooms : ['the', 'canker', 'blooms', 'have', 'full', 'as', 'deep', 'a', 'dye']
# 1
# perfumed : ['as', 'the', 'perfumed', 'tincture', 'of', 'the', 'roses']
# 2
# discloses : ['when', "summer's", 'breath', 'their', 'masked', 'buds', 'discloses']
# 3
# unwooed : ['they', 'live', 'unwooed', 'and', 'unrespected', 'fade']
# 2
# deaths : ['of', 'their', 'sweet', 'deaths', 'are', 'sweetest', 'odours', 'made']
# 1
# odours : ['of', 'their', 'sweet', 'deaths', 'are', 'sweetest', 'odours', 'made']
# 2
# distills : ['when', 'that', 'shall', 'fade', 'my', 'verse', 'distills', 'your', 'truth']
# 2
# gilded : ['not', 'marble', 'nor', 'the', 'gilded', 'monuments']
# 2
# monuments : ['not', 'marble', 'nor', 'the', 'gilded', 'monuments']
# 3
# unswept : ['than', 'unswept', 'stone', 'besmeared', 'with', 'sluttish', 'time']
# 2
# besmeared : ['than', 'unswept', 'stone', 'besmeared', 'with', 'sluttish', 'time']
# 2
# statues : ['when', 'wasteful', 'war', 'shall', 'statues', 'overturn']
# 2
# broils : ['and', 'broils', 'root', 'out', 'the', 'work', 'of', 'masonry']
# 1
# mars : ['nor', 'mars', 'his', 'sword', 'nor', "war's", 'quick', 'fire', 'shall', 'burn']
# 1
# war's : ['nor', 'mars', 'his', 'sword', 'nor', "war's", 'quick', 'fire', 'shall', 'burn']
# 1
# all-oblivious : ["'gainst", 'death', 'and', 'all-oblivious', 'enmity']
# 4
# lovers' : ['you', 'live', 'in', 'this', 'and', 'dwell', 'in', "lovers'", 'eyes']
# 2
# blunter : ['thy', 'edge', 'should', 'blunter', 'be', 'than', 'appetite']
# 2
# allayed : ['which', 'but', 'to-day', 'by', 'feeding', 'is', 'allayed']
# 2
# to-morrow : ['to-morrow', 'sharpened', 'in', 'his', 'former', 'might']
# 3
# sharpened : ['to-morrow', 'sharpened', 'in', 'his', 'former', 'might']
# 2
# dulness : ['the', 'spirit', 'of', 'love', 'with', 'a', 'perpetual', 'dulness']
# 2
# banks : ['come', 'daily', 'to', 'the', 'banks', 'that', 'when', 'they', 'see']
# 1
# wished : ['makes', "summer's", 'welcome', 'thrice', 'more', 'wished', 'more', 'rare']
# 1
# services : ['nor', 'services', 'to', 'do', 'till', 'you', 'require']
# 3
# world-without-end : ['nor', 'dare', 'i', 'chide', 'the', 'world-without-end', 'hour']
# 4
# affairs : ['where', 'you', 'may', 'be', 'or', 'your', 'affairs', 'suppose']
# 2
# thinks : ['though', 'you', 'do', 'any', 'thing', 'he', 'thinks', 'no', 'ill']
# 1
# god : ['that', 'god', 'forbid', 'that', 'made', 'me', 'first', 'your', 'slave']
# 1
# privilage : ['that', 'you', 'your', 'self', 'may', 'privilage', 'your', 'time']
# 3
# self-doing : ['your', 'self', 'to', 'pardon', 'of', 'self-doing', 'crime']
# 3
# brains : ['hath', 'been', 'before', 'how', 'are', 'our', 'brains', 'beguiled']
# 1
# labouring : ['which', 'labouring', 'for', 'invention', 'bear', 'amis']
# 3
# amis : ['which', 'labouring', 'for', 'invention', 'bear', 'amis']
# 2
# courses : ['even', 'of', 'five', 'hundred', 'courses', 'of', 'the', 'sun']
# 2
# mended : ['whether', 'we', 'are', 'mended', 'or', 'whether', 'better', 'they']
# 2
# wits : ['o', 'sure', 'i', 'am', 'the', 'wits', 'of', 'former', 'days']
# 1
# subjects : ['to', 'subjects', 'worse', 'have', 'given', 'admiring', 'praise']
# 2
# waves : ['like', 'as', 'the', 'waves', 'make', 'towards', 'the', 'pebbled', 'shore']
# 1
# goes : ['each', 'changing', 'place', 'with', 'that', 'which', 'goes', 'before']
# 1
# crawls : ['crawls', 'to', 'maturity', 'wherewith', 'being', 'crowned']
# 1
# delves : ['and', 'delves', 'the', 'parallels', 'in', "beauty's", 'brow']
# 1
# parallels : ['and', 'delves', 'the', 'parallels', 'in', "beauty's", 'brow']
# 3
# feeds : ['feeds', 'on', 'the', 'rarities', 'of', "nature's", 'truth']
# 1
# rarities : ['feeds', 'on', 'the', 'rarities', 'of', "nature's", 'truth']
# 3
# slumbers : ['dost', 'thou', 'desire', 'my', 'slumbers', 'should', 'be', 'broken']
# 2
# send'st : ['is', 'it', 'thy', 'spirit', 'that', 'thou', "send'st", 'from', 'thee']
# 1
# shames : ['to', 'find', 'out', 'shames', 'and', 'idle', 'hours', 'in', 'me']
# 1
# possesseth : ['sin', 'of', 'self-love', 'possesseth', 'all', 'mine', 'eye']
# 3
# grounded : ['it', 'is', 'so', 'grounded', 'inward', 'in', 'my', 'heart']
# 2
# worths : ['as', 'i', 'all', 'other', 'in', 'all', 'worths', 'surmount']
# 1
# beated : ['beated', 'and', 'chopt', 'with', 'tanned', 'antiquity']
# 2
# chopt : ['beated', 'and', 'chopt', 'with', 'tanned', 'antiquity']
# 1
# tanned : ['beated', 'and', 'chopt', 'with', 'tanned', 'antiquity']
# 1
# self-loving : ['self', 'so', 'self-loving', 'were', 'iniquity']
# 3
# o'erworn : ['with', "time's", 'injurious', 'hand', 'crushed', 'and', "o'erworn"]
# 2
# travelled : ['hath', 'travelled', 'on', 'to', "age's", 'steepy', 'night']
# 2
# age's : ['hath', 'travelled', 'on', 'to', "age's", 'steepy', 'night']
# 2
# he's : ['and', 'all', 'those', 'beauties', 'whereof', 'now', "he's", 'king']
# 1
# lover's : ['my', 'sweet', "love's", 'beauty', 'though', 'my', "lover's", 'life']
# 2
# rich-proud : ['the', 'rich-proud', 'cost', 'of', 'outworn', 'buried', 'age']
# 2
# outworn : ['the', 'rich-proud', 'cost', 'of', 'outworn', 'buried', 'age']
# 2
# towers : ['when', 'sometime', 'lofty', 'towers', 'i', 'see', 'down-rased']
# 2
# down-rased : ['when', 'sometime', 'lofty', 'towers', 'i', 'see', 'down-rased']
# 2
# fears : ['but', 'weep', 'to', 'have', 'that', 'which', 'it', 'fears', 'to', 'lose']
# 1
# o'ersways : ['but', 'sad', 'mortality', "o'ersways", 'their', 'power']
# 2
# batt'ring : ['against', 'the', 'wrackful', 'siege', 'of', "batt'ring", 'days']
# 2
# rocks : ['when', 'rocks', 'impregnable', 'are', 'not', 'so', 'stout']
# 1
# gates : ['nor', 'gates', 'of', 'steel', 'so', 'strong', 'but', 'time', 'decays']
# 1
# decays : ['nor', 'gates', 'of', 'steel', 'so', 'strong', 'but', 'time', 'decays']
# 2
# trimmed : ['and', 'needy', 'nothing', 'trimmed', 'in', 'jollity']
# 1
# purest : ['and', 'purest', 'faith', 'unhappily', 'forsworn']
# 2
# unhappily : ['and', 'purest', 'faith', 'unhappily', 'forsworn']
# 4
# shamefully : ['and', 'gilded', 'honour', 'shamefully', 'misplaced']
# 3
# misplaced : ['and', 'gilded', 'honour', 'shamefully', 'misplaced']
# 2
# rudely : ['and', 'maiden', 'virtue', 'rudely', 'strumpeted']
# 2
# strumpeted : ['and', 'maiden', 'virtue', 'rudely', 'strumpeted']
# 3
# wrongfully : ['and', 'right', 'perfection', 'wrongfully', 'disgraced']
# 3
# limping : ['and', 'strength', 'by', 'limping', 'sway', 'disabled']
# 2
# doctor-like : ['and', 'folly', 'doctor-like', 'controlling', 'skill']
# 3
# miscalled : ['and', 'simple', 'truth', 'miscalled', 'simplicity']
# 2
# beggared : ['beggared', 'of', 'blood', 'to', 'blush', 'through', 'lively', 'veins']
# 2
# veins : ['beggared', 'of', 'blood', 'to', 'blush', 'through', 'lively', 'veins']
# 1
# gains : ['and', 'proud', 'of', 'many', 'lives', 'upon', 'his', 'gains']
# 1
# stores : ['o', 'him', 'she', 'stores', 'to', 'show', 'what', 'wealth', 'she', 'had']
# 1
# signs : ['before', 'these', 'bastard', 'signs', 'of', 'fair', 'were', 'born']
# 1
# tresses : ['before', 'the', 'golden', 'tresses', 'of', 'the', 'dead']
# 2
# sepulchres : ['the', 'right', 'of', 'sepulchres', 'were', 'shorn', 'away']
# 3
# another's : ['making', 'no', 'summer', 'of', "another's", 'green']
# 3
# robbing : ['robbing', 'no', 'old', 'to', 'dress', 'his', 'beauty', 'new']
# 2
# tongues : ['all', 'tongues', 'the', 'voice', 'of', 'souls', 'give', 'thee', 'that', 'due']
# 1
# uttering : ['uttering', 'bare', 'truth', 'even', 'so', 'as', 'foes', 'commend']
# 3
# accents : ['in', 'other', 'accents', 'do', 'this', 'praise', 'confound']
# 2
# churls : ['then', 'churls', 'their', 'thoughts', 'although', 'their', 'eyes', 'were', 'kind']
# 1
# weeds : ['to', 'thy', 'fair', 'flower', 'add', 'the', 'rank', 'smell', 'of', 'weeds']
# 1
# matcheth : ['but', 'why', 'thy', 'odour', 'matcheth', 'not', 'thy', 'show']
# 2
# slander's : ['for', "slander's", 'mark', 'was', 'ever', 'yet', 'the', 'fair']
# 2
# flies : ['a', 'crow', 'that', 'flies', 'in', "heaven's", 'sweetest', 'air']
# 1
# wooed : ['thy', 'worth', 'the', 'greater', 'being', 'wooed', 'of', 'time']
# 1
# present'st : ['and', 'thou', "present'st", 'a', 'pure', 'unstained', 'prime']
# 2
# unstained : ['and', 'thou', "present'st", 'a', 'pure', 'unstained', 'prime']
# 2
# passed : ['thou', 'hast', 'passed', 'by', 'the', 'ambush', 'of', 'young', 'days']
# 1
# charged : ['either', 'not', 'assailed', 'or', 'victor', 'being', 'charged']
# 1
# kingdoms : ['then', 'thou', 'alone', 'kingdoms', 'of', 'hearts', 'shouldst', 'owe']
# 2
# vilest : ['from', 'this', 'vile', 'world', 'with', 'vilest', 'worms', 'to', 'dwell']
# 2
# shamed : ['for', 'i', 'am', 'shamed', 'by', 'that', 'which', 'i', 'bring', 'forth']
# 1
# boughs : ['upon', 'those', 'boughs', 'which', 'shake', 'against', 'the', 'cold']
# 1
# ruined : ['bare', 'ruined', 'choirs', 'where', 'late', 'the', 'sweet', 'birds', 'sang']
# 1
# choirs : ['bare', 'ruined', 'choirs', 'where', 'late', 'the', 'sweet', 'birds', 'sang']
# 2
# birds : ['bare', 'ruined', 'choirs', 'where', 'late', 'the', 'sweet', 'birds', 'sang']
# 1
# seest : ['in', 'me', 'thou', 'seest', 'the', 'twilight', 'of', 'such', 'day']
# 1
# fadeth : ['as', 'after', 'sunset', 'fadeth', 'in', 'the', 'west']
# 2
# seals : ["death's", 'second', 'self', 'that', 'seals', 'up', 'all', 'in', 'rest']
# 1
# death-bed : ['as', 'the', 'death-bed', 'whereon', 'it', 'must', 'expire']
# 2
# nourished : ['consumed', 'with', 'that', 'which', 'it', 'was', 'nourished', 'by']
# 2
# perceiv'st : ['this', 'thou', "perceiv'st", 'which', 'makes', 'thy', 'love', 'more', 'strong']
# 2
# reviewest : ['when', 'thou', 'reviewest', 'this', 'thou', 'dost', 'review']
# 3
# dregs : ['so', 'then', 'thou', 'hast', 'but', 'lost', 'the', 'dregs', 'of', 'life']
# 1
# wretch's : ['the', 'coward', 'conquest', 'of', 'a', "wretch's", 'knife']
# 2
# contains : ['the', 'worth', 'of', 'that', 'is', 'that', 'which', 'it', 'contains']
# 2
# remains : ['and', 'that', 'is', 'this', 'and', 'this', 'with', 'thee', 'remains']
# 2
# sweet-seasoned : ['or', 'as', 'sweet-seasoned', 'showers', 'are', 'to', 'the', 'ground']
# 3
# showers : ['or', 'as', 'sweet-seasoned', 'showers', 'are', 'to', 'the', 'ground']
# 2
# filching : ['doubting', 'the', 'filching', 'age', 'will', 'steal', 'his', 'treasure']
# 2
# counting : ['now', 'counting', 'best', 'to', 'be', 'with', 'you', 'alone']
# 2
# bettered : ['then', 'bettered', 'that', 'the', 'world', 'may', 'see', 'my', 'pleasure']
# 2
# feasting : ['sometime', 'all', 'full', 'with', 'feasting', 'on', 'your', 'sight']
# 2
# starved : ['and', 'by', 'and', 'by', 'clean', 'starved', 'for', 'a', 'look']
# 1
# possessing : ['possessing', 'or', 'pursuing', 'no', 'delight']
# 3
# pursuing : ['possessing', 'or', 'pursuing', 'no', 'delight']
# 3
# gluttoning : ['or', 'gluttoning', 'on', 'all', 'or', 'all', 'away']
# 3
# new-found : ['to', 'new-found', 'methods', 'and', 'to', 'compounds', 'strange']
# 2
# methods : ['to', 'new-found', 'methods', 'and', 'to', 'compounds', 'strange']
# 2
# compounds : ['to', 'new-found', 'methods', 'and', 'to', 'compounds', 'strange']
# 2
# mind's : ['these', 'vacant', 'leaves', 'thy', "mind's", 'imprint', 'will', 'bear']
# 1
# graves : ['of', 'mouthed', 'graves', 'will', 'give', 'thee', 'memory']
# 1
# dial's : ['thou', 'by', 'thy', "dial's", 'shady', 'stealth', 'mayst', 'know']
# 1
# blanks : ['commit', 'to', 'these', 'waste', 'blanks', 'and', 'thou', 'shalt', 'find']
# 1
# delivered : ['those', 'children', 'nursed', 'delivered', 'from', 'thy', 'brain']
# 3
# offices : ['these', 'offices', 'so', 'oft', 'as', 'thou', 'wilt', 'look']
# 3
# invoked : ['so', 'oft', 'have', 'i', 'invoked', 'thee', 'for', 'my', 'muse']
# 2
# feathers : ['have', 'added', 'feathers', 'to', 'the', "learned's", 'wing']
# 2
# learned's : ['have', 'added', 'feathers', 'to', 'the', "learned's", 'wing']
# 2
# others' : ['in', "others'", 'works', 'thou', 'dost', 'but', 'mend', 'the', 'style']
# 2
# works : ['in', "others'", 'works', 'thou', 'dost', 'but', 'mend', 'the', 'style']
# 1
# arts : ['and', 'arts', 'with', 'thy', 'sweet', 'graces', 'graced', 'be']
# 1
# deserves : ['deserves', 'the', 'travail', 'of', 'a', 'worthier', 'pen']
# 2
# worthier : ['deserves', 'the', 'travail', 'of', 'a', 'worthier', 'pen']
# 2
# pays : ['he', 'robs', 'thee', 'of', 'and', 'pays', 'it', 'thee', 'again']
# 1
# behaviour : ['from', 'thy', 'behaviour', 'beauty', 'doth', 'he', 'give']
# 3
# owes : ['since', 'what', 'he', 'owes', 'thee', 'thou', 'thy', 'self', 'dost', 'pay']
# 1
# spends : ['and', 'in', 'the', 'praise', 'thereof', 'spends', 'all', 'his', 'might']
# 1
# proudest : ['the', 'humble', 'as', 'the', 'proudest', 'sail', 'doth', 'bear']
# 2
# wilfully : ['on', 'your', 'broad', 'main', 'doth', 'wilfully', 'appear']
# 3
# shallowest : ['your', 'shallowest', 'help', 'will', 'hold', 'me', 'up', 'afloat']
# 3
# wrecked : ['or', 'being', 'wrecked', 'i', 'am', 'a', 'worthless', 'boat']
# 1
# entombed : ['when', 'you', 'entombed', 'in', "men's", 'eyes', 'shall', 'lie']
# 2
# o'er-read : ['which', 'eyes', 'not', 'yet', 'created', 'shall', "o'er-read"]
# 2
# breathers : ['when', 'all', 'the', 'breathers', 'of', 'this', 'world', 'are', 'dead']
# 2
# breathes : ['where', 'breath', 'most', 'breathes', 'even', 'in', 'the', 'mouths', 'of', 'men']
# 1
# mouths : ['where', 'breath', 'most', 'breathes', 'even', 'in', 'the', 'mouths', 'of', 'men']
# 1
# o'erlook : ['and', 'therefore', 'mayst', 'without', 'attaint', "o'erlook"]
# 2
# writers : ['the', 'dedicated', 'words', 'which', 'writers', 'use']
# 2
# time-bettering : ['some', 'fresher', 'stamp', 'of', 'the', 'time-bettering', 'days']
# 4
# devised : ['and', 'do', 'so', 'love', 'yet', 'when', 'they', 'have', 'devised']
# 2
# sympathized : ['thou', 'truly', 'fair', 'wert', 'truly', 'sympathized']
# 3
# true-telling : ['in', 'true', 'plain', 'words', 'by', 'thy', 'true-telling', 'friend']
# 3
# cheeks : ['where', 'cheeks', 'need', 'blood', 'in', 'thee', 'it', 'is', 'abused']
# 1
# abused : ['where', 'cheeks', 'need', 'blood', 'in', 'thee', 'it', 'is', 'abused']
# 2
# immured : ['in', 'whose', 'confine', 'immured', 'is', 'the', 'store']
# 2
# writes : ['but', 'he', 'that', 'writes', 'of', 'you', 'if', 'he', 'can', 'tell']
# 1
# dignifies : ['that', 'you', 'are', 'you', 'so', 'dignifies', 'his', 'story']
# 3
# blessings : ['you', 'to', 'your', 'beauteous', 'blessings', 'add', 'a', 'curse']
# 2
# praises : ['being', 'fond', 'on', 'praise', 'which', 'makes', 'your', 'praises', 'worse']
# 2
# comments : ['while', 'comments', 'of', 'your', 'praise', 'richly', 'compiled']
# 2
# compiled : ['while', 'comments', 'of', 'your', 'praise', 'richly', 'compiled']
# 2
# muses : ['and', 'precious', 'phrase', 'by', 'all', 'the', 'muses', 'filed']
# 2
# filed : ['and', 'precious', 'phrase', 'by', 'all', 'the', 'muses', 'filed']
# 1
# unlettered : ['and', 'like', 'unlettered', 'clerk', 'still', 'cry', 'amen']
# 3
# affords : ['to', 'every', 'hymn', 'that', 'able', 'spirit', 'affords']
# 2
# praised : ['hearing', 'you', 'praised', 'i', 'say', "'tis", 'so', "'tis", 'true']
# 1
# hindmost : ['though', 'words', 'come', 'hindmost', 'holds', 'his', 'rank', 'before']
# 2
# spirits : ['was', 'it', 'his', 'spirit', 'by', 'spirits', 'taught', 'to', 'write']
# 2
# compeers : ['no', 'neither', 'he', 'nor', 'his', 'compeers', 'by', 'night']
# 2
# astonished : ['giving', 'him', 'aid', 'my', 'verse', 'astonished']
# 3
# gulls : ['which', 'nightly', 'gulls', 'him', 'with', 'intelligence']
# 1
# victors : ['as', 'victors', 'of', 'my', 'silence', 'cannot', 'boast']
# 2
# releasing : ['the', 'charter', 'of', 'thy', 'worth', 'gives', 'thee', 'releasing']
# 3
# bonds : ['my', 'bonds', 'in', 'thee', 'are', 'all', 'determinate']
# 1
# granting : ['for', 'how', 'do', 'i', 'hold', 'thee', 'but', 'by', 'thy', 'granting']
# 2
# swerving : ['and', 'so', 'my', 'patent', 'back', 'again', 'is', 'swerving']
# 2
# attainted : ['of', 'faults', 'concealed', 'wherein', 'i', 'am', 'attainted']
# 3
# injuries : ['the', 'injuries', 'that', 'to', 'my', 'self', 'i', 'do']
# 3
# double-vantage : ['doing', 'thee', 'vantage', 'double-vantage', 'me']
# 4
# desired : ['to', 'set', 'a', 'form', 'upon', 'desired', 'change']
# 2
# walks : ['be', 'absent', 'from', 'thy', 'walks', 'and', 'in', 'my', 'tongue']
# 1
# wronk : ['lest', 'i', 'too', 'much', 'profane', 'should', 'do', 'it', 'wronk']
# 1
# after-loss : ['and', 'do', 'not', 'drop', 'in', 'for', 'an', 'after-loss']
# 3
# 'scaped : ['ah', 'do', 'not', 'when', 'my', 'heart', 'hath', "'scaped", 'this', 'sorrow']
# 11
# conquered : ['come', 'in', 'the', 'rearward', 'of', 'a', 'conquered', 'woe']
# 2
# purposed : ['to', 'linger', 'out', 'a', 'purposed', 'overthrow']
# 2
# griefs : ['when', 'other', 'petty', 'griefs', 'have', 'done', 'their', 'spite']
# 1
# strains : ['and', 'other', 'strains', 'of', 'woe', 'which', 'now', 'seem', 'woe']
# 1
# compared : ['compared', 'with', 'loss', 'of', 'thee', 'will', 'not', 'seem', 'so']
# 2
# garments : ['some', 'in', 'their', 'garments', 'though', 'new-fangled', 'ill']
# 2
# new-fangled : ['some', 'in', 'their', 'garments', 'though', 'new-fangled', 'ill']
# 3
# hawks : ['some', 'in', 'their', 'hawks', 'and', 'hounds', 'some', 'in', 'their', 'horse']
# 1
# hounds : ['some', 'in', 'their', 'hawks', 'and', 'hounds', 'some', 'in', 'their', 'horse']
# 1
# finds : ['wherein', 'it', 'finds', 'a', 'joy', 'above', 'the', 'rest']
# 1
# particulars : ['but', 'these', 'particulars', 'are', 'not', 'my', 'measure']
# 4
# richer : ['richer', 'than', 'wealth', 'prouder', 'than', "garments'", 'costs']
# 2
# prouder : ['richer', 'than', 'wealth', 'prouder', 'than', "garments'", 'costs']
# 2
# garments' : ['richer', 'than', 'wealth', 'prouder', 'than', "garments'", 'costs']
# 2
# costs : ['richer', 'than', 'wealth', 'prouder', 'than', "garments'", 'costs']
# 1
# horses : ['of', 'more', 'delight', 'than', 'hawks', 'and', 'horses', 'be']
# 2
# wretchcd : ['all', 'this', 'away', 'and', 'me', 'most', 'wretchcd', 'make']
# 2
# depends : ['for', 'it', 'depends', 'upon', 'that', 'love', 'of', 'thine']
# 2
# what's : ['but', "what's", 'so', 'blessed-fair', 'that', 'fears', 'no', 'blot']
# 1
# blessed-fair : ['but', "what's", 'so', 'blessed-fair', 'that', 'fears', 'no', 'blot']
# 3
# supposing : ['so', 'shall', 'i', 'live', 'supposing', 'thou', 'art', 'true']
# 3
# deceived : ['like', 'a', 'deceived', 'husband', 'so', "love's", 'face']
# 2
# altered : ['may', 'still', 'seem', 'love', 'to', 'me', 'though', 'altered', 'new']
# 2
# many's : ['in', "many's", 'looks', 'the', 'false', "heart's", 'history']
# 2
# moods : ['is', 'writ', 'in', 'moods', 'and', 'frowns', 'and', 'wrinkles', 'strange']
# 1
# frowns : ['is', 'writ', 'in', 'moods', 'and', 'frowns', 'and', 'wrinkles', 'strange']
# 1
# workings : ["whate'er", 'thy', 'thoughts', 'or', 'thy', "heart's", 'workings', 'be']
# 2
# eve's : ['how', 'like', "eve's", 'apple', 'doth', 'thy', 'beauty', 'grow']
# 1
# tibey : ['tibey', 'are', 'the', 'lords', 'and', 'owners', 'of', 'their', 'faces']
# 2
# lords : ['tibey', 'are', 'the', 'lords', 'and', 'owners', 'of', 'their', 'faces']
# 1
# owners : ['tibey', 'are', 'the', 'lords', 'and', 'owners', 'of', 'their', 'faces']
# 2
# stewards : ['others', 'but', 'stewards', 'of', 'their', 'excellence']
# 2
# outbraves : ['the', 'basest', 'weed', 'outbraves', 'his', 'dignity']
# 2
# sourest : ['for', 'sweetest', 'things', 'turn', 'sourest', 'by', 'their', 'deeds']
# 2
# lilies : ['lilies', 'that', 'fester', 'smell', 'far', 'worse', 'than', 'weeds']
# 2
# naming : ['naming', 'thy', 'name', 'blesses', 'an', 'ill', 'report']
# 2
# blesses : ['naming', 'thy', 'name', 'blesses', 'an', 'ill', 'report']
# 2
# vices : ['o', 'what', 'a', 'mansion', 'have', 'those', 'vices', 'got']
# 2
# hardest : ['the', 'hardest', 'knife', 'ill-used', 'doth', 'lose', 'his', 'edge']
# 2
# throned : ['as', 'on', 'the', 'finger', 'of', 'a', 'throned', 'queen']
# 1
# esteemed : ['the', 'basest', 'jewel', 'will', 'be', 'well', 'esteemed']
# 2
# errors : ['so', 'are', 'those', 'errors', 'that', 'in', 'thee', 'are', 'seen']
# 2
# truths : ['to', 'truths', 'translated', 'and', 'for', 'true', 'things', 'deemed']
# 1
# translated : ['to', 'truths', 'translated', 'and', 'for', 'true', 'things', 'deemed']
# 3
# deemed : ['to', 'truths', 'translated', 'and', 'for', 'true', 'things', 'deemed']
# 1
# lambs : ['how', 'many', 'lambs', 'might', 'the', 'stern', 'wolf', 'betray']
# 1
# gazers : ['how', 'many', 'gazers', 'mightst', 'thou', 'lead', 'away']
# 2
# freezings : ['what', 'freezings', 'have', 'i', 'felt', 'what', 'dark', 'days', 'seen']
# 2
# december's : ['what', 'old', "december's", 'bareness', 'everywhere']
# 3
# widowed : ['like', 'widowed', 'wombs', 'after', 'their', "lords'", 'decease']
# 2
# wombs : ['like', 'widowed', 'wombs', 'after', 'their', "lords'", 'decease']
# 1
# lords' : ['like', 'widowed', 'wombs', 'after', 'their', "lords'", 'decease']
# 1
# seemed : ['yet', 'this', 'abundant', 'issue', 'seemed', 'to', 'me']
# 1
# orphans : ['but', 'hope', 'of', 'orphans', 'and', 'unfathered', 'fruit']
# 2
# pleasures : ['for', 'summer', 'and', 'his', 'pleasures', 'wait', 'on', 'thee']
# 2
# dreading : ['that', 'leaves', 'look', 'pale', 'dreading', 'the', "winter's", 'near']
# 2
# proud-pied : ['when', 'proud-pied', 'april', 'dressed', 'in', 'all', 'his', 'trim']
# 2
# saturn : ['that', 'heavy', 'saturn', 'laughed', 'and', 'leaped', 'with', 'him']
# 2
# laughed : ['that', 'heavy', 'saturn', 'laughed', 'and', 'leaped', 'with', 'him']
# 1
# leaped : ['that', 'heavy', 'saturn', 'laughed', 'and', 'leaped', 'with', 'him']
# 1
# lays : ['yet', 'nor', 'the', 'lays', 'of', 'birds', 'nor', 'the', 'sweet', 'smell']
# 1
# lily's : ['nor', 'did', 'i', 'wonder', 'at', 'the', "lily's", 'white']
# 2
# figures : ['they', 'were', 'but', 'sweet', 'but', 'figures', 'of', 'delight']
# 2
# forget'st : ['where', 'art', 'thou', 'muse', 'that', 'thou', "forget'st", 'so', 'long']
# 2
# spend'st : ["spend'st", 'thou', 'thy', 'fury', 'on', 'some', 'worthless', 'song']
# 1
# spoils : ['and', 'make', "time's", 'spoils', 'despised', 'everywhere']
# 1
# prevent'st : ['so', 'thou', "prevent'st", 'his', 'scythe', 'and', 'crooked', 'knife']
# 2
# 'truth : ["'truth", 'needs', 'no', 'colour', 'with', 'his', 'colour', 'fixed']
# 1
# intermixed' : ['but', 'best', 'is', 'best', 'if', 'never', "intermixed'"]
# 3
# for't : ['excuse', 'not', 'silence', 'so', "for't", 'lies', 'in', 'thee']
# 1
# ages : ['and', 'to', 'be', 'praised', 'of', 'ages', 'yet', 'to', 'be']
# 2
# strengthened : ['my', 'love', 'is', 'strengthened', 'though', 'more', 'weak', 'in', 'seeming']
# 2
# merchandized : ['that', 'love', 'is', 'merchandized', 'whose', 'rich', 'esteeming']
# 3
# esteeming : ['that', 'love', 'is', 'merchandized', 'whose', 'rich', 'esteeming']
# 3
# owner's : ['the', "owner's", 'tongue', 'doth', 'publish', 'every', 'where']
# 2
# stops : ['and', 'stops', 'her', 'pipe', 'in', 'growth', 'of', 'riper', 'days']
# 1
# burthens : ['but', 'that', 'wild', 'music', 'burthens', 'every', 'bough']
# 2
# appears : ['look', 'in', 'your', 'glass', 'and', 'there', 'appears', 'a', 'face']
# 2
# over-goes : ['that', 'over-goes', 'my', 'blunt', 'invention', 'quite']
# 3
# dulling : ['dulling', 'my', 'lines', 'and', 'doing', 'me', 'disgrace']
# 2
# verses : ['for', 'to', 'no', 'other', 'pass', 'my', 'verses', 'tend']
# 2
# gifts : ['than', 'of', 'your', 'graces', 'and', 'your', 'gifts', 'to', 'tell']
# 1
# seems : ['such', 'seems', 'your', 'beauty', 'still', 'three', 'winters', 'cold']
# 1
# forests : ['have', 'from', 'the', 'forests', 'shook', 'three', "summers'", 'pride']
# 2
# summers' : ['have', 'from', 'the', 'forests', 'shook', 'three', "summers'", 'pride']
# 2
# springs : ['three', 'beauteous', 'springs', 'to', 'yellow', 'autumn', 'turned']
# 1
# turned : ['three', 'beauteous', 'springs', 'to', 'yellow', 'autumn', 'turned']
# 1
# perfumes : ['three', 'april', 'perfumes', 'in', 'three', 'hot', 'junes', 'burned']
# 2
# junes : ['three', 'april', 'perfumes', 'in', 'three', 'hot', 'junes', 'burned']
# 1
# perceived : ['steal', 'from', 'his', 'figure', 'and', 'no', 'pace', 'perceived']
# 2
# songs : ['since', 'all', 'alike', 'my', 'songs', 'and', 'praises', 'be']
# 1
# expressing : ['one', 'thing', 'expressing', 'leaves', 'out', 'difference']
# 3
# themes : ['three', 'themes', 'in', 'one', 'which', 'wondrous', 'scope', 'affords']
# 1
# wasted : ['when', 'in', 'the', 'chronicle', 'of', 'wasted', 'time']
# 2
# descriptions : ['i', 'see', 'descriptions', 'of', 'the', 'fairest', 'wights']
# 3
# wights : ['i', 'see', 'descriptions', 'of', 'the', 'fairest', 'wights']
# 1
# ladies : ['in', 'praise', 'of', 'ladies', 'dead', 'and', 'lovely', 'knights']
# 2
# knights : ['in', 'praise', 'of', 'ladies', 'dead', 'and', 'lovely', 'knights']
# 1
# prophecies : ['so', 'all', 'their', 'praises', 'are', 'but', 'prophecies']
# 3
# prefiguring : ['of', 'this', 'our', 'time', 'all', 'you', 'prefiguring']
# 4
# looked : ['and', 'for', 'they', 'looked', 'but', 'with', 'divining', 'eyes']
# 1
# dreaming : ['of', 'the', 'wide', 'world', 'dreaming', 'on', 'things', 'to', 'come']
# 2
# endured : ['the', 'mortal', 'moon', 'hath', 'her', 'eclipse', 'endured']
# 2
# augurs : ['and', 'the', 'sad', 'augurs', 'mock', 'their', 'own', 'presage']
# 2
# incertainties : ['incertainties', 'now', 'crown', 'themselves', 'assured']
# 4
# proclaims : ['and', 'peace', 'proclaims', 'olives', 'of', 'endless', 'age']
# 2
# olives : ['and', 'peace', 'proclaims', 'olives', 'of', 'endless', 'age']
# 2
# drops : ['now', 'with', 'the', 'drops', 'of', 'this', 'most', 'balmy', 'time']
# 1
# subscribes : ['my', 'love', 'looks', 'fresh', 'and', 'death', 'to', 'me', 'subscribes']
# 2
# insults : ['while', 'he', 'insults', "o'er", 'dull', 'and', 'speechless', 'tribes']
# 2
# tribes : ['while', 'he', 'insults', "o'er", 'dull', 'and', 'speechless', 'tribes']
# 1
# tyrants' : ['when', "tyrants'", 'crests', 'and', 'tombs', 'of', 'brass', 'are', 'spent']
# 2
# crests : ['when', "tyrants'", 'crests', 'and', 'tombs', 'of', 'brass', 'are', 'spent']
# 1
# tombs : ['when', "tyrants'", 'crests', 'and', 'tombs', 'of', 'brass', 'are', 'spent']
# 1
# prayers : ['nothing', 'sweet', 'boy', 'but', 'yet', 'like', 'prayers', 'divine']
# 2
# weighs : ['weighs', 'not', 'the', 'dust', 'and', 'injury', 'of', 'age']
# 1
# ranged : ['that', 'is', 'my', 'home', 'of', 'love', 'if', 'i', 'have', 'ranged']
# 1
# travels : ['like', 'him', 'that', 'travels', 'i', 'return', 'again']
# 2
# exchanged : ['just', 'to', 'the', 'time', 'not', 'with', 'the', 'time', 'exchanged']
# 2
# reigned : ['never', 'believe', 'though', 'in', 'my', 'nature', 'reigned']
# 1
# frailties : ['all', 'frailties', 'that', 'besiege', 'all', 'kinds', 'of', 'blood']
# 2
# kinds : ['all', 'frailties', 'that', 'besiege', 'all', 'kinds', 'of', 'blood']
# 1
# preposterously : ['that', 'it', 'could', 'so', 'preposterously', 'be', 'stained']
# 4
# stained : ['that', 'it', 'could', 'so', 'preposterously', 'be', 'stained']
# 1
# gored : ['gored', 'mine', 'own', 'thoughts', 'sold', 'cheap', 'what', 'is', 'most', 'dear']
# 1
# offences : ['made', 'old', 'offences', 'of', 'affections', 'new']
# 3
# affections : ['made', 'old', 'offences', 'of', 'affections', 'new']
# 3
# blenches : ['these', 'blenches', 'gave', 'my', 'heart', 'another', 'youth']
# 2
# essays : ['and', 'worse', 'essays', 'proved', 'thee', 'my', 'best', 'of', 'love']
# 2
# proved : ['and', 'worse', 'essays', 'proved', 'thee', 'my', 'best', 'of', 'love']
# 1
# newer : ['on', 'newer', 'proof', 'to', 'try', 'an', 'older', 'friend']
# 2
# older : ['on', 'newer', 'proof', 'to', 'try', 'an', 'older', 'friend']
# 2
# breeds : ['than', 'public', 'means', 'which', 'public', 'manners', 'breeds']
# 1
# receives : ['thence', 'comes', 'it', 'that', 'my', 'name', 'receives', 'a', 'brand']
# 2
# dyer's : ['to', 'what', 'it', 'works', 'in', 'like', 'the', "dyer's", 'hand']
# 2
# renewed : ['pity', 'me', 'then', 'and', 'wish', 'i', 'were', 'renewed']
# 2
# potions : ['potions', 'of', 'eisel', "'gainst", 'my', 'strong', 'infection']
# 2
# stamped : ['which', 'vulgar', 'scandal', 'stamped', 'upon', 'my', 'brow']
# 1
# o'er-green : ['so', 'you', "o'er-green", 'my', 'bad', 'my', 'good', 'allow']
# 2
# steeled : ['that', 'my', 'steeled', 'sense', 'or', 'changes', 'right', 'or', 'wrong']
# 1
# changes : ['that', 'my', 'steeled', 'sense', 'or', 'changes', 'right', 'or', 'wrong']
# 2
# voices : ['of', "others'", 'voices', 'that', 'my', "adder's", 'sense']
# 2
# adder's : ['of', "others'", 'voices', 'that', 'my', "adder's", 'sense']
# 2
# governs : ['and', 'that', 'which', 'governs', 'me', 'to', 'go', 'about']
# 2
# delivers : ['for', 'it', 'no', 'form', 'delivers', 'to', 'the', 'heart']
# 3
# objects : ['of', 'his', 'quick', 'objects', 'hath', 'the', 'mind', 'no', 'part']
# 2
# rud'st : ['for', 'if', 'it', 'see', 'the', "rud'st", 'or', 'gentlest', 'sight']
# 1
# gentlest : ['for', 'if', 'it', 'see', 'the', "rud'st", 'or', 'gentlest', 'sight']
# 2
# deformed'st : ['the', 'most', 'sweet', 'favour', 'or', "deformed'st", 'creature']
# 2
# shapes : ['the', 'crow', 'or', 'dove', 'it', 'shapes', 'them', 'to', 'your', 'feature']
# 1
# maketh : ['my', 'most', 'true', 'mind', 'thus', 'maketh', 'mine', 'untrue']
# 2
# monarch's : ['drink', 'up', 'the', "monarch's", 'plague', 'this', 'flattery']
# 2
# monsters : ['to', 'make', 'of', 'monsters', 'and', 'things', 'indigest']
# 2
# cherubins : ['such', 'cherubins', 'as', 'your', 'sweet', 'self', 'resemble']
# 3
# creating : ['creating', 'every', 'bad', 'a', 'perfect', 'best']
# 3
# beams : ['as', 'fast', 'as', 'objects', 'to', 'his', 'beams', 'assemble']
# 1
# drinks : ['and', 'my', 'great', 'mind', 'most', 'kingly', 'drinks', 'it', 'up']
# 1
# 'greeing : ['mine', 'eye', 'well', 'knows', 'what', 'with', 'his', 'gust', 'is', "'greeing"]
# 2
# poisoned : ['if', 'it', 'be', 'poisoned', "'tis", 'the', 'lesser', 'sin']
# 2
# accidents : ['but', 'reckoning', 'time', 'whose', 'millioned', 'accidents']
# 3
# vows : ['creep', 'in', "'twixt", 'vows', 'and', 'change', 'decrees', 'of', 'kings']
# 1
# decrees : ['creep', 'in', "'twixt", 'vows', 'and', 'change', 'decrees', 'of', 'kings']
# 2
# sharp'st : ['tan', 'sacred', 'beauty', 'blunt', 'the', "sharp'st", 'intents']
# 1
# intents : ['tan', 'sacred', 'beauty', 'blunt', 'the', "sharp'st", 'intents']
# 2
# minds : ['divert', 'strong', 'minds', 'to', 'the', 'course', 'of', "alt'ring", 'things']
# 1
# alt'ring : ['divert', 'strong', 'minds', 'to', 'the', 'course', 'of', "alt'ring", 'things']
# 2
# fearing : ['alas', 'why', 'fearing', 'of', "time's", 'tyranny']
# 2
# 'now : ['might', 'i', 'not', 'then', 'say', "'now", 'i', 'love', 'you', "best'"]
# 1
# best' : ['might', 'i', 'not', 'then', 'say', "'now", 'i', 'love', 'you', "best'"]
# 1
# crowning : ['crowning', 'the', 'present', 'doubting', 'of', 'the', 'rest']
# 2
# impediments : ['admit', 'impediments', 'love', 'is', 'not', 'love']
# 4
# alters : ['which', 'alters', 'when', 'it', 'alteration', 'finds']
# 2
# bends : ['or', 'bends', 'with', 'the', 'remover', 'to', 'remove']
# 1
# ever-fixed : ['o', 'no', 'it', 'is', 'an', 'ever-fixed', 'mark']
# 3
# tempests : ['that', 'looks', 'on', 'tempests', 'and', 'is', 'never', 'shaken']
# 2
# wand'ring : ['it', 'is', 'the', 'star', 'to', 'every', "wand'ring", 'bark']
# 2
# worth's : ['whose', "worth's", 'unknown', 'although', 'his', 'height', 'be', 'taken']
# 1
# lips : ["love's", 'not', "time's", 'fool', 'though', 'rosy', 'lips', 'and', 'cheeks']
# 1
# sickle's : ['within', 'his', 'bending', "sickle's", 'compass', 'come']
# 2
# weeks : ['love', 'alters', 'not', 'with', 'his', 'brief', 'hours', 'and', 'weeks']
# 1
# scanted : ['accuse', 'me', 'thus', 'that', 'i', 'have', 'scanted', 'all']
# 2
# dear-purchased : ['and', 'given', 'to', 'time', 'your', 'own', 'dear-purchased', 'right']
# 3
# hoisted : ['that', 'i', 'have', 'hoisted', 'sail', 'to', 'all', 'the', 'winds']
# 2
# wilfulness : ['book', 'both', 'my', 'wilfulness', 'and', 'errors', 'down']
# 3
# wakened : ['but', 'shoot', 'not', 'at', 'me', 'in', 'your', 'wakened', 'hate']
# 2
# maladies : ['as', 'to', 'prevent', 'our', 'maladies', 'unseen']
# 3
# ne'er-cloying : ['even', 'so', 'being', 'full', 'of', 'your', "ne'er-cloying", 'sweetness']
# 3
# sauces : ['to', 'bitter', 'sauces', 'did', 'i', 'frame', 'my', 'feeding']
# 2
# needing : ['to', 'be', 'diseased', 'ere', 'that', 'there', 'was', 'true', 'needing']
# 2
# t' : ['thus', 'policy', 'in', 'love', "t'", 'anticipate']
# 0
# ills : ['the', 'ills', 'that', 'were', 'not', 'grew', 'to', 'faults', 'assured']
# 1
# cured : ['which', 'rank', 'of', 'goodness', 'would', 'by', 'ill', 'be', 'cured']
# 1
# drugs : ['drugs', 'poison', 'him', 'that', 'so', 'feil', 'sick', 'of', 'you']
# 1
# feil : ['drugs', 'poison', 'him', 'that', 'so', 'feil', 'sick', 'of', 'you']
# 1
# limbecks : ['distilled', 'from', 'limbecks', 'foul', 'as', 'hell', 'within']
# 2
# applying : ['applying', 'fears', 'to', 'hopes', 'and', 'hopes', 'to', 'fears']
# 3
# hopes : ['applying', 'fears', 'to', 'hopes', 'and', 'hopes', 'to', 'fears']
# 1
# spheres : ['how', 'have', 'mine', 'eyes', 'out', 'of', 'their', 'spheres', 'been', 'fitted']
# 1
# fitted : ['how', 'have', 'mine', 'eyes', 'out', 'of', 'their', 'spheres', 'been', 'fitted']
# 2
# rebuked : ['so', 'i', 'return', 'rebuked', 'to', 'my', 'content']
# 2
# befriends : ['that', 'you', 'were', 'once', 'unkind', 'befriends', 'me', 'now']
# 2
# nerves : ['unless', 'my', 'nerves', 'were', 'brass', 'or', 'hammered', 'steel']
# 1
# hammered : ['unless', 'my', 'nerves', 'were', 'brass', 'or', 'hammered', 'steel']
# 2
# unkindness : ['for', 'if', 'you', 'were', 'by', 'my', 'unkindness', 'shaken']
# 3
# y'have : ['as', 'i', 'by', 'yours', "y'have", 'passed', 'a', 'hell', 'of', 'time']
# 1
# suffered : ['to', 'weigh', 'how', 'once', 'i', 'suffered', 'in', 'your', 'crime']
# 2
# deepest : ['my', 'deepest', 'sense', 'how', 'hard', 'true', 'sorrow', 'hits']
# 2
# hits : ['my', 'deepest', 'sense', 'how', 'hard', 'true', 'sorrow', 'hits']
# 1
# tendered : ['and', 'soon', 'to', 'you', 'as', 'you', 'to', 'me', 'then', 'tendered']
# 2
# wounded : ['the', 'humble', 'salve', 'which', 'wounded', 'bosoms', 'fits']
# 2
# bosoms : ['the', 'humble', 'salve', 'which', 'wounded', 'bosoms', 'fits']
# 2
# fits : ['the', 'humble', 'salve', 'which', 'wounded', 'bosoms', 'fits']
# 1
# becomes : ['but', 'that', 'your', 'trespass', 'now', 'becomes', 'a', 'fee']
# 2
# ransoms : ['mine', 'ransoms', 'yours', 'and', 'yours', 'must', 'ransom', 'me']
# 2
# frailer : ['or', 'on', 'my', 'frailties', 'why', 'are', 'frailer', 'spies']
# 2
# spies : ['or', 'on', 'my', 'frailties', 'why', 'are', 'frailer', 'spies']
# 1
# wills : ['which', 'in', 'their', 'wills', 'count', 'bad', 'what', 'i', 'think', 'good']
# 1
# abuses : ['at', 'my', 'abuses', 'reckon', 'up', 'their', 'own']
# 3
# tables : ['thy', 'gift', 'thy', 'tables', 'are', 'within', 'my', 'brain']
# 2
# charactered : ['full', 'charactered', 'with', 'lasting', 'memory']
# 3
# missed : ['of', 'thee', 'thy', 'record', 'never', 'can', 'be', 'missed']
# 1
# tallies : ['nor', 'need', 'i', 'tallies', 'thy', 'dear', 'love', 'to', 'score']
# 2
# pyramids : ['thy', 'pyramids', 'built', 'up', 'with', 'newer', 'might']
# 3
# dressings : ['they', 'are', 'but', 'dressings', 'of', 'a', 'former', 'sight']
# 2
# dates : ['our', 'dates', 'are', 'brief', 'and', 'therefore', 'we', 'admire']
# 1
# registers : ['thy', 'registers', 'and', 'thee', 'i', 'both', 'defy']
# 3
# wond'ring : ['not', "wond'ring", 'at', 'the', 'present', 'nor', 'the', 'past']
# 2
# records : ['for', 'thy', 'records', 'and', 'what', 'we', 'see', 'doth', 'lie']
# 2
# gathered : ['weeds', 'among', 'weeds', 'or', 'flowers', 'with', 'flowers', 'gathered']
# 2
# builded : ['no', 'it', 'was', 'builded', 'far', 'from', 'accident']
# 2
# suffers : ['it', 'suffers', 'not', 'in', 'smiling', 'pomp', 'nor', 'falls']
# 2
# smiling : ['it', 'suffers', 'not', 'in', 'smiling', 'pomp', 'nor', 'falls']
# 2
# falls : ['it', 'suffers', 'not', 'in', 'smiling', 'pomp', 'nor', 'falls']
# 1
# thralled : ['under', 'the', 'blow', 'of', 'thralled', 'discontent']
# 1
# leases : ['which', 'works', 'on', 'leases', 'of', 'short-numbered', 'hours']
# 2
# short-numbered : ['which', 'works', 'on', 'leases', 'of', 'short-numbered', 'hours']
# 3
# hugely : ['but', 'all', 'alone', 'stands', 'hugely', 'politic']
# 2
# drowns : ['that', 'it', 'nor', 'grows', 'with', 'heat', 'nor', 'drowns', 'with', 'showers']
# 1
# fools : ['to', 'this', 'i', 'witness', 'call', 'the', 'fools', 'of', 'time']
# 1
# were't : ["were't", 'aught', 'to', 'me', 'i', 'bore', 'the', 'canopy']
# 1
# honouring : ['with', 'my', 'extern', 'the', 'outward', 'honouring']
# 3
# bases : ['or', 'laid', 'great', 'bases', 'for', 'eternity']
# 2
# ruining : ['which', 'proves', 'more', 'short', 'than', 'waste', 'or', 'ruining']
# 2
# dwellers : ['have', 'i', 'not', 'seen', 'dwellers', 'on', 'form', 'and', 'favour']
# 2
# forgoing : ['for', 'compound', 'sweet', 'forgoing', 'simple', 'savour']
# 3
# savour : ['for', 'compound', 'sweet', 'forgoing', 'simple', 'savour']
# 2
# ...
# 2
# vowing : ['in', 'vowing', 'new', 'hate', 'after', 'new', 'love', 'bearing']
# 2
# oaths' : ['but', 'why', 'of', 'two', "oaths'", 'breach', 'do', 'i', 'accuse', 'thee']
# 1
# oaths : ['for', 'all', 'my', 'vows', 'are', 'oaths', 'but', 'to', 'misuse', 'thee']
# 1
# cupid : ['cupid', 'laid', 'by', 'his', 'brand', 'and', 'fell', 'asleep']
# 2
# dian's : ['a', 'maid', 'of', "dian's", 'this', 'advantage', 'found']
# 2
# love-kindling : ['and', 'his', 'love-kindling', 'fire', 'did', 'quickly', 'steep']
# 3
# valley-fountain : ['in', 'a', 'cold', 'valley-fountain', 'of', 'that', 'ground']
# 4
# seeting : ['and', 'grew', 'a', 'seeting', 'bath', 'which', 'yet', 'men', 'prove']
# 2
# new-fired : ['but', 'at', 'my', "mistress'", 'eye', "love's", 'brand', 'new-fired']
# 2
# hied : ['and', 'thither', 'hied', 'a', 'sad', 'distempered', 'guest']
# 1
# distempered : ['and', 'thither', 'hied', 'a', 'sad', 'distempered', 'guest']
# 3
# love-god : ['the', 'little', 'love-god', 'lying', 'once', 'asleep']
# 2
# heart-inflaming : ['laid', 'by', 'his', 'side', 'his', 'heart-inflaming', 'brand']
# 4
# nymphs : ['whilst', 'many', 'nymphs', 'that', 'vowed', 'chaste', 'life', 'to', 'keep']
# 1
# vowed : ['whilst', 'many', 'nymphs', 'that', 'vowed', 'chaste', 'life', 'to', 'keep']
# 1
# legions : ['which', 'many', 'legions', 'of', 'true', 'hearts', 'had', 'warmed']
# 2
# warmed : ['which', 'many', 'legions', 'of', 'true', 'hearts', 'had', 'warmed']
# 1
# quenched : ['this', 'brand', 'she', 'quenched', 'in', 'a', 'cool', 'well', 'by']
# 1
# discased : ['for', 'men', 'discased', 'but', 'i', 'my', "mistress'", 'thrall']
# 2
# heats : ["love's", 'fire', 'heats', 'water', 'water', 'cools', 'not', 'love']
# 1
# cools : ["love's", 'fire', 'heats', 'water', 'water', 'cools', 'not', 'love']
# 1
# {'fawn': 1,
#  'pardon': 2,
#  'yellow': 2,
#  'four': 1,
#  'hath': 1,
#  'sleep': 1,
#  "friend's": 1,
#  'hanging': 2,
#  'mansion': 2,
#  'appetite': 3,
#  'evermore': 3,
#  'hate': 1,
#  'forget': 2,
#  'whose': 1,
#  'feeding': 2,
#  'vile': 1,
#  'granting': 2,
#  'sweetest': 2,
#  'presents': 2,
#  'walks': 1,
#  "there's": 1,
#  'whatsoever': 4,
#  'under': 2,
#  'lord': 1,
#  'sorry': 2,
#  'pride': 1,
#  'sway': 1,
#  'worth': 1,
#  'wondrous': 2,
#  'tune': 1,
#  'discased': 2,
#  'dispense': 2,
#  'hadst': 1,
#  'inhearse': 2,
#  "women's": 2,
#  'shoot': 1,
#  'every': 3,
#  'foul': 1,
#  'nourished': 2,
#  "o'er-read": 2,
#  'special': 2,
#  'believed': 2,
#  'uttering': 3,
#  'prize': 1,
#  'unrest': 2,
#  'graced': 1,
#  'succession': 3,
#  'graces': 1,
#  'triumph': 2,
#  'enjoy': 2,
#  'charter': 2,
#  'force': 1,
#  'tired': 1,
#  'awake': 2,
#  'razed': 1,
#  'out-going': 3,
#  'assure': 2,
#  'tires': 1,
#  'crave': 1,
#  'persuade': 2,
#  'quill': 1,
#  'even': 2,
#  'beated': 2,
#  'captain': 2,
#  'hide': 1,
#  "ne'er": 1,
#  'solemn': 2,
#  'thunder': 2,
#  'fingers': 2,
#  'liberty': 3,
#  'children': 2,
#  'worser': 2,
#  'inheritors': 4,
#  'above': 2,
#  'matcheth': 2,
#  'new': 1,
#  'poorly': 2,
#  'ever': 2,
#  'told': 1,
#  'deemed': 1,
#  'merchandized': 3,
#  'sinks': 1,
#  'join': 1,
#  'never': 2,
#  'here': 1,
#  'herd': 1,
#  'beck': 1,
#  "sweet'st": 1,
#  'pursuit': 2,
#  'active': 2,
#  'spies': 1,
#  'a-doting': 3,
#  'effectually': 5,
#  'dry': 1,
#  'resty': 2,
#  'substance': 2,
#  'gaol': 1,
#  'leaves': 1,
#  'climbed': 1,
#  'credit': 2,
#  'smoke': 1,
#  'permit': 2,
#  'bettered': 2,
#  'mistake': 2,
#  'settled': 2,
#  'politic': 3,
#  'golden': 2,
#  'swearing': 2,
#  'divide': 2,
#  'motley': 2,
#  'blessed-fair': 3,
#  'sorrows': 2,
#  'patience': 2,
#  'stern': 1,
#  'costly': 2,
#  'glance': 1,
#  "light's": 1,
#  'plot': 1,
#  'budding': 2,
#  'would': 1,
#  'recured': 2,
#  "world's": 1,
#  'junes': 1,
#  'music': 2,
#  'therefore': 2,
#  'survive': 2,
#  'gilding': 2,
#  'tell': 1,
#  'breathe': 1,
#  'leese': 1,
#  'unbless': 2,
#  'holy': 2,
#  'wary': 2,
#  'brings': 1,
#  'muse': 1,
#  'herein': 2,
#  'grief': 1,
#  'glass': 1,
#  'warm': 1,
#  'excellent': 3,
#  'robbing': 2,
#  'ward': 1,
#  'hold': 1,
#  'striving': 2,
#  'must': 1,
#  'me': 1,
#  'locked': 1,
#  'room': 1,
#  'err': 1,
#  'rights': 1,
#  'work': 1,
#  'eclipse': 2,
#  'roof': 1,
#  'meadows': 2,
#  'ere': 1,
#  'leaped': 1,
#  'revenues': 3,
#  'my': 1,
#  'example': 3,
#  'lodged': 1,
#  'phrase': 1,
#  'subtleties': 3,
#  'fresher': 1,
#  'wane': 1,
#  'unjust': 2,
#  'honey': 2,
#  'foist': 1,
#  'kingdoms': 2,
#  'respose': 2,
#  'keep': 1,
#  'worse': 1,
#  'ceremony': 4,
#  "consum'st": 2,
#  'gusts': 1,
#  'provide': 2,
#  'dignifies': 3,
#  'travel': 2,
#  'indirectly': 4,
#  'feature': 2,
#  'wights': 1,
#  'how': 1,
#  'hot': 1,
#  'writers': 2,
#  'low': 1,
#  'answer': 2,
#  'gate': 1,
#  'dignified': 3,
#  "o'er-snowed": 2,
#  'blanks': 1,
#  'beauty': 2,
#  'after': 2,
#  'wrong': 1,
#  'lay': 1,
#  'lap': 1,
#  'wronk': 1,
#  "rud'st": 1,
#  'revolt': 2,
#  'greet': 1,
#  'purging': 2,
#  'wink': 1,
#  'maintain': 2,
#  'green': 1,
#  'keeps': 1,
#  'alack': 2,
#  'wouldst': 1,
#  'wind': 1,
#  'bed-vow': 2,
#  'determinate': 4,
#  'couplement': 3,
#  'after-loss': 3,
#  'office': 2,
#  'consent': 2,
#  'profaned': 2,
#  'sickly': 2,
#  'fortify': 3,
#  'ghastly': 2,
#  'strangle': 2,
#  "bestow'st": 2,
#  'wrought': 1,
#  'before': 2,
#  'better': 2,
#  'fade': 1,
#  'carve': 1,
#  'hidden': 2,
#  'savour': 2,
#  'then': 1,
#  'them': 1,
#  'blots': 1,
#  'enrich': 2,
#  'thee': 1,
#  "truth's": 1,
#  'break': 1,
#  "winter's": 2,
#  'diseased': 2,
#  'they': 1,
#  'glazed': 1,
#  'one': 1,
#  'silver': 2,
#  'shadows': 2,
#  'rhetoric': 3,
#  'brightness': 2,
#  'slavery': 3,
#  'rocks': 1,
#  'herald': 2,
#  'victories': 3,
#  'needing': 2,
#  'each': 1,
#  'wantonly': 3,
#  'dulness': 2,
#  'went': 1,
#  'side': 1,
#  'luck': 1,
#  'true-telling': 3,
#  'woes': 1,
#  'concord': 2,
#  "'will'": 1,
#  'taught': 1,
#  'forgot': 2,
#  'misprision': 3,
#  'whit': 1,
#  'truant': 2,
#  'array': 2,
#  'borne': 1,
#  'contend': 2,
#  'large': 1,
#  'decree': 2,
#  'weakness': 2,
#  'sang': 1,
#  'god': 1,
#  'forty': 2,
#  "run'st": 1,
#  'content': 2,
#  'laid': 1,
#  'heart-inflaming': 4,
#  'heavenly': 3,
#  'got': 1,
#  'marigold': 3,
#  'forth': 1,
#  'prizing': 2,
#  'assured': 2,
#  'written': 2,
#  'fadeth': 2,
#  'hang': 1,
#  'deceived': 2,
#  'eternal': 3,
#  'given': 2,
#  'free': 1,
#  'mourning': 2,
#  'mistaking': 3,
#  'bestow': 2,
#  'whereupon': 3,
#  'rain': 1,
#  'crowned': 1,
#  'mistress': 2,
#  'knit': 1,
#  'wantonness': 3,
#  "receiv'st": 2,
#  'created': 2,
#  'days': 1,
#  'bears': 1,
#  'renew': 2,
#  'tempting': 2,
#  'unknown': 2,
#  'tied': 1,
#  'potions': 2,
#  'loud': 1,
#  'ruinate': 3,
#  'purpose': 2,
#  'separable': 4,
#  'untutored': 3,
#  'already': 3,
#  'crowning': 2,
#  'hearsay': 2,
#  "'greeing": 2,
#  'rank': 1,
#  'hearing': 2,
#  'jealous': 2,
#  'featured': 2,
#  'another': 3,
#  'sober': 3,
#  'filching': 2,
#  'exchequer': 3,
#  'usurer': 3,
#  'top': 1,
#  'hawks': 1,
#  'millioned': 2,
#  'master': 4,
#  'too': 1,
#  'dwell': 1,
#  'bitter': 2,
#  'monuments': 3,
#  'saith': 1,
#  'broils': 1,
#  'feathers': 2,
#  'griefs': 1,
#  'took': 1,
#  'wisdom': 2,
#  'wardrobe': 2,
#  "youth's": 1,
#  'character': 3,
#  'begins': 2,
#  'distance': 2,
#  "here's": 1,
#  'coward': 2,
#  "mother's": 2,
#  'bitterness': 3,
#  'idly': 2,
#  'matter': 2,
#  'idle': 2,
#  'invention': 3,
#  'flame': 1,
#  'friend': 1,
#  'deserving': 3,
#  'askance': 2,
#  'knights': 1,
#  'feeling': 2,
#  'powers': 2,
#  'swift-footed': 3,
#  'fashion': 2,
#  'sees': 1,
#  'gaudy': 2,
#  "mind's": 1,
#  'modern': 2,
#  'mind': 1,
#  'mine': 1,
#  'spent': 1,
#  'manner': 2,
#  'amiss': 2,
#  'bewailed': 2,
#  "deserv'st": 2,
#  'churl': 1,
#  'seem': 1,
#  'seek': 1,
#  'tells': 1,
#  'contents': 2,
#  'praising': 2,
#  'strength': 1,
#  'neck': 1,
#  'snow': 1,
#  'sound': 1,
#  'chest': 1,
#  'subjects': 2,
#  'laughed': 1,
#  'pilgrimage': 3,
#  'rider': 2,
#  'aggravate': 3,
#  'maiden': 2,
#  'though': 1,
#  'object': 2,
#  'dial': 2,
#  'justify': 3,
#  'dulling': 2,
#  'errors': 2,
#  'ashes': 2,
#  'disarmed': 2,
#  'grave': 1,
#  'shalt': 1,
#  'constancy': 3,
#  'consumed': 1,
#  'flow': 1,
#  'breathes': 1,
#  'steeled': 1,
#  'points': 1,
#  'wrecked': 1,
#  'fitted': 2,
#  'reserve': 2,
#  'wild': 1,
#  'renewed': 2,
#  'bait': 1,
#  'oaths': 1,
#  'enjoyer': 3,
#  'ending': 2,
#  'poison': 2,
#  'earth': 1,
#  'bail': 1,
#  'enjoyed': 2,
#  'bearer': 2,
#  'touches': 2,
#  'copy': 2,
#  'proposed': 2,
#  'spite': 1,
#  'herself': 2,
#  'cupid': 2,
#  'bliss': 1,
#  'touched': 1,
#  'rich': 1,
#  'pursuing': 3,
#  'mend': 1,
#  "'thou": 1,
#  'borrowed': 2,
#  'do': 2,
#  'blenches': 2,
#  'forsworn': 2,
#  'stop': 1,
#  'perceive': 2,
#  'leisure': 2,
#  'raiment': 2,
#  'gored': 1,
#  'bootless': 2,
#  'spirit': 2,
#  'despite': 2,
#  'report': 2,
#  'saturn': 2,
#  'seemly': 2,
#  'runs': 1,
#  'increasing': 1,
#  'bar': 1,
#  'exchanged': 2,
#  'beseem': 2,
#  'thrusts': 1,
#  'doting': 2,
#  'twice': 1,
#  'eyelids': 2,
#  'esteeming': 3,
#  'hasten': 2,
#  'steal': 1,
#  'farther': 2,
#  'unprovident': 4,
#  'penance': 2,
#  "wond'ring": 2,
#  'unrespected': 3,
#  'fair': 1,
#  'habit': 2,
#  'imitate': 3,
#  'proclaims': 2,
#  'depends': 2,
#  'corrupt': 2,
#  'best': 1,
#  'subject': 2,
#  'said': 1,
#  'temptation': 3,
#  "bett'ring": 2,
#  'away': 2,
#  'sail': 1,
#  'bier': 1,
#  'madding': 2,
#  'wilful-slow': 3,
#  'mud': 1,
#  'score': 1,
#  'finger': 2,
#  'pebbled': 2,
#  'scorn': 1,
#  'drawn': 1,
#  'enlighten': 3,
#  'preserve': 2,
#  'warrior': 2,
#  'we': 1,
#  'men': 1,
#  'terms': 1,
#  'parallels': 3,
#  'nature': 2,
#  'weak': 1,
#  'ignorance': 3,
#  'authorizing': 4,
#  'disdaineth': 3,
#  'wear': 1,
#  'diest': 1,
#  'news': 1,
#  'debt': 1,
#  'tempests': 2,
#  'pity': 2,
#  'foes': 1,
#  'goddess': 2,
#  'accident': 3,
#  'disdain': 2,
#  'fault': 1,
#  'ill': 1,
#  'against': 2,
#  'brag': 1,
#  'receives': 2,
#  'faces': 2,
#  'exceeds': 2,
#  'expense': 2,
#  'groans': 1,
#  'asked': 1,
#  'suggest': 2,
#  'vexed': 1,
#  'honouring': 3,
#  'burthen': 2,
#  'height': 1,
#  'hers': 1,
#  'prone': 1,
#  'springs': 1,
#  'over-plus': 3,
#  'trust': 1,
#  'heals': 1,
#  'speak': 1,
#  'yellowed': 2,
#  'unhappily': 4,
#  'puts': 1,
#  'eager': 2,
#  'time-bettering': 4,
#  'three': 1,
#  'been': 1,
#  'particulars': 4,
#  'twain': 1,
#  'presagers': 3,
#  'interest': 3,
#  'incertainty': 4,
#  'privilege': 3,
#  'vermilion': 3,
#  'lovely': 2,
#  'thrice': 1,
#  'idol': 2,
#  'life': 1,
#  "brav'ry": 2,
#  'easy': 2,
#  'erred': 1,
#  'drugs': 1,
#  'maladies': 3,
#  'decrepit': 3,
#  'dote': 1,
#  'child': 1,
#  'catch': 1,
#  'doth': 1,
#  'erst': 1,
#  'gracious': 2,
#  'physician': 3,
#  'east': 1,
#  'air': 1,
#  'lesser': 2,
#  'ugly': 2,
#  'near': 1,
#  'suppose': 2,
#  'aid': 1,
#  'voice': 1,
#  'weakens': 2,
#  'played': 1,
#  'is': 1,
#  'it': 1,
#  'defeated': 2,
#  'shame': 1,
#  'to-morrow': 3,
#  'splendour': 2,
#  'in': 1,
#  'bounteous': 3,
#  'if': 1,
#  'grown': 1,
#  'wooing': 2,
#  'memorial': 4,
#  'awakes': 2,
#  'cools': 1,
#  'patent': 2,
#  'things': 1,
#  'make': 1,
#  'wound': 1,
#  "lords'": 1,
#  'beside': 2,
#  'bosoms': 2,
#  "th'": 1,
#  'several': 3,
#  'grows': 1,
#  'entitled': 3,
#  'lusty': 2,
#  'fairly': 2,
#  'tops': 1,
#  'evil': 2,
#  'hand': 1,
#  'delight': 2,
#  'supposing': 3,
#  'dark': 1,
#  'bequest': 2,
#  'blamed': 1,
#  'thoughts': 1,
#  'censures': 2,
#  'kept': 1,
#  'thy': 1,
#  'singleness': 3,
#  'sweetness': 2,
#  'possessed': 2,
#  'humble': 2,
#  'inherit': 3,
#  'ocean': 2,
#  'ragged': 2,
#  'fulness': 2,
#  'greatest': 1,
#  'incapable': 4,
#  'mother': 2,
#  'hearts': 1,
#  'the': 1,
#  'cure': 1,
#  'yours': 1,
#  'left': 1,
#  'reeks': 1,
#  'just': 1,
#  'wasteful': 2,
#  'yea': 1,
#  "poet's": 2,
#  'unfair': 2,
#  'repose': 2,
#  'verses': 2,
#  'maketh': 2,
#  'thanks': 1,
#  'swears': 1,
#  'prognosticate': 4,
#  'plight': 1,
#  'yet': 1,
#  'succeeding': 3,
#  'vices': 2,
#  'adding': 2,
#  'dearer': 2,
#  'compeers': 2,
#  'had': 1,
#  'counted': 2,
#  'alchemy': 3,
#  'belongs': 2,
#  'beloved': 4,
#  'prison': 2,
#  'hap': 1,
#  'pitiful': 3,
#  'save': 1,
#  'gave': 1,
#  "others'": 2,
#  'dignity': 3,
#  'spacious': 2,
#  'reviewest': 3,
#  'birth': 1,
#  'wanting': 2,
#  'shadow': 2,
#  'dreams': 1,
#  "picture's": 2,
#  'desire': 2,
#  'brought': 1,
#  "feed'st": 1,
#  'gift': 1,
#  'new-found': 2,
#  'vilest': 2,
#  'offices': 3,
#  'night': 1,
#  'hung': 1,
#  'antique': 2,
#  'right': 1,
#  'old': 1,
#  'flatter': 2,
#  "war's": 1,
#  'deaf': 1,
#  'short-numbered': 3,
#  'dead': 1,
#  'born': 1,
#  'dear': 1,
#  'altered': 2,
#  'bore': 1,
#  'guess': 1,
#  'creep': 1,
#  'enemies': 3,
#  'for': 1,
#  "bosom's": 2,
#  'rehearse': 2,
#  'comments': 2,
#  'foe': 1,
#  'denied': 2,
#  'bold': 1,
#  'burn': 1,
#  'divining': 3,
#  'shifting': 2,
#  'losing': 4,
#  'taker': 2,
#  'peep': 1,
#  'disdains': 2,
#  'shaken': 2,
#  'proceed': 2,
#  'theirs': 1,
#  'coral': 2,
#  'haply': 2,
#  'frailer': 2,
#  'o': 1,
#  'costs': 1,
#  'despair': 2,
#  'guilty': 2,
#  'cherish': 2,
#  'commit': 2,
#  'lacked': 1,
#  'bath': 1,
#  'raised': 1,
#  'faint': 1,
#  'presence': 2,
#  'civil': 2,
#  'pays': 1,
#  'nought': 1,
#  'bound': 1,
#  'son': 1,
#  'down': 1,
#  'lies': 1,
#  'refined': 2,
#  "pour'st": 1,
#  'methods': 2,
#  'strangely': 2,
#  'despised': 2,
#  'jealousy': 3,
#  'sovereign': 3,
#  'fight': 1,
#  'virgin': 2,
#  'way': 1,
#  'call': 1,
#  'was': 1,
#  'war': 1,
#  'happy': 2,
#  'head': 1,
#  'faring': 2,
#  'form': 1,
#  'statute': 2,
#  'crown': 1,
#  'becoming': 3,
#  'forgetful': 3,
#  'fore': 1,
#  'back': 1,
#  'heinous': 2,
#  'pricked': 1,
#  'heat': 1,
#  'hear': 1,
#  'odours': 2,
#  'learned': 2,
#  'astonished': 3,
#  'blindness': 2,
#  'removed': 2,
#  'true': 1,
#  'deepest': 2,
#  'absent': 2,
#  'lilies': 2,
#  'captive': 2,
#  'extremity': 4,
#  "for't": 1,
#  'bids': 1,
#  'until': 2,
#  'crystal': 2,
#  'unfathered': 3,
#  'adore': 2,
#  'anew': 2,
#  'engraft': 2,
#  'bide': 1,
#  'latch': 1,
#  'trim': 1,
#  'disgrace': 2,
#  'ornaments': 3,
#  'fury': 2,
#  'sinful': 2,
#  'steep-up': 2,
#  "beauty's": 2,
#  'hungry': 2,
#  'huswife': 2,
#  'sometime': 2,
#  'subsist': 2,
#  'shines': 1,
#  'face': 1,
#  'injurious': 4,
#  'posting': 2,
#  'willingly': 3,
#  'looked': 1,
#  'dying': 2,
#  'no': 2,
#  'excel': 2,
#  "lov'st": 1,
#  'actor': 2,
#  'thriftless': 2,
#  'despising': 3,
#  'falsely': 2,
#  'papers': 2,
#  'tie': 1,
#  'vanished': 2,
#  'smell': 1,
#  'eternity': 4,
#  'picture': 2,
#  'intend': 2,
#  'phoenix': 2,
#  'pyramids': 3,
#  'dies': 1,
#  'welcome': 2,
#  'first-born': 2,
#  'present-absent': 4,
#  'fell': 1,
#  'reign': 1,
#  'rolling': 2,
#  'pierced': 1,
#  'seeing': 2,
#  'died': 1,
#  'wrackful': 2,
#  'to-day': 1,
#  'longer': 2,
#  'blushing': 2,
#  'daily': 2,
#  'cheater': 2,
#  'teeth': 1,
#  "dian's": 2,
#  'laws': 1,
#  'restored': 2,
#  'songs': 1,
#  'whoever': 3,
#  'varying': 3,
#  "perceiv'st": 2,
#  'souls': 1,
#  'invent': 2,
#  'engrafted': 3,
#  'leads': 1,
#  'continual': 4,
#  'slandered': 2,
#  'idolatry': 4,
#  'abundant': 3,
#  'retention': 3,
#  'mounted': 2,
#  'praises': 2,
#  'father': 2,
#  'confounds': 2,
#  'vex': 1,
#  'charge': 1,
#  'praised': 1,
#  'suffered': 2,
#  'addeth': 2,
#  'furrows': 2,
#  'abundance': 3,
#  'strumpeted': 3,
#  'string': 1,
#  'advantage': 3,
#  'drudge': 1,
#  'fleece': 1,
#  'votary': 3,
#  'mourn': 1,
#  'advised': 2,
#  'word': 1,
#  'trouble': 2,
#  'feeble': 2,
#  'cool': 1,
#  "soul's": 1,
#  'perceived': 2,
#  'clouds': 1,
#  'level': 2,
#  'did': 1,
#  'die': 1,
#  'dig': 1,
#  "best'": 1,
#  'leave': 1,
#  'excellence': 3,
#  'burned': 1,
#  'quick': 1,
#  'prevent': 2,
#  'brave': 1,
#  'says': 1,
#  'fearing': 2,
#  "offender's": 3,
#  'double-vantage': 4,
#  'sigh': 1,
#  'wherefore': 2,
#  'cost': 1,
#  'patient': 2,
#  'fear': 1,
#  'indigest': 3,
#  'hymn': 1,
#  "fleet'st": 1,
#  'curse': 1,
#  'appear': 2,
#  'assistance': 3,
#  'contracted': 3,
#  'favour': 2,
#  'pleased': 1,
#  'suspect': 2,
#  'goes': 1,
#  'pine': 1,
#  'appeal': 2,
#  'filled': 1,
#  "april's": 2,
#  'prescriptions': 3,
#  'wail': 1,
#  'honour': 1,
#  'clerk': 1,
#  'water': 2,
#  'entertain': 3,
#  'alone': 2,
#  'appears': 2,
#  'change': 1,
#  'blunter': 2,
#  'boy': 1,
#  'boast': 1,
#  'root': 1,
#  'wherever': 3,
#  'bow': 1,
#  'spheres': 1,
#  'shook': 1,
#  'recounting': 3,
#  'stained': 1,
#  'love': 1,
#  'humour': 1,
#  'tempteth': 2,
#  'bloody': 2,
#  'withal': 2,
#  'betraying': 3,
#  'surmount': 2,
#  'swallowed': 2,
#  "suff'ring": 2,
#  "o'erworn": 2,
#  'voices': 2,
#  'wealth': 1,
#  'prove': 1,
#  'sake': 3,
#  'confounded': 3,
#  'angry': 2,
#  'give': 1,
#  'only': 2,
#  "batt'ring": 2,
#  'wrongs': 1,
#  'live': 1,
#  'wood': 1,
#  'prey': 1,
#  'memory': 3,
#  'scope': 1,
#  'loving': 2,
#  "love's": 1,
#  'fierce': 1,
#  'riot': 2,
#  'sessions': 2,
#  'towers': 2,
#  'neglected': 3,
#  'acceptable': 4,
#  "strength's": 1,
#  'drown': 1,
#  'everywhere': 4,
#  'virtue': 2,
#  'robe': 1,
#  'epitaph': 3,
#  'fly': 1,
#  'impair': 2,
#  'sheds': 1,
#  'car': 1,
#  'soul': 1,
#  'purge': 1,
#  'hardest': 2,
#  'sour': 1,
#  'can': 1,
#  'growing': 1,
#  'making': 2,
#  "prevent'st": 2,
#  'deceased': 2,
#  'breeds': 1,
#  'heart': 1,
#  'dedicated': 1,
#  "servant's": 2,
#  'want': 1,
#  'figure': 2,
#  'predict': 2,
#  'sense': 1,
#  'distillation': 4,
#  'heard': 1,
#  'critic': 2,
#  'purity': 3,
#  'hides': 1,
#  "mak'st": 1,
#  'provoke': 2,
#  'stole': 1,
#  'bereft': 2,
#  'churls': 1,
#  'winter': 2,
#  'dress': 1,
#  'divided': 3,
#  'undivided': 4,
#  'vainly': 2,
#  'trophies': 2,
#  "lour'st": 1,
#  'write': 1,
#  'till': 1,
#  'sword': 1,
#  'husbandry': 3,
#  'sworn': 1,
#  ...}

# %%
save_file = open(SYLL_DICT, 'rb')
syll_dict = pickle.load(save_file)
save_file.close()
print len(syll_dict)
# Out:
# 3190

# %%
print syll_dict
# Out:
# {'test': 1}
